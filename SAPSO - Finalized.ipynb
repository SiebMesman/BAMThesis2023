# %% [markdown]
# #### Importing the necessary packages:

# %%
# Standard packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import rand
import random
import math
# Train-test split creation
from sklearn.model_selection import train_test_split
# Oversampling
from imblearn.over_sampling import SMOTE
# Pipeline creation
from imblearn.pipeline import Pipeline
# Performing search over tuning grid
from sklearn.model_selection import GridSearchCV, StratifiedKFold
# Transforming columns to arrays
from sklearn.compose import ColumnTransformer
# Standardazing the data
from sklearn.preprocessing import StandardScaler
# Importing the performance metrics
from sklearn.metrics import make_scorer, roc_auc_score, accuracy_score, recall_score, precision_score, auc, roc_curve, confusion_matrix, f1_score
# The Logistic Regression
from sklearn.linear_model import LogisticRegression
# The KNN classifier
from sklearn.neighbors import KNeighborsClassifier
# The LGBM classifier
import lightgbm as ltb
# Surpress warning
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Importing and prepping data

# %%
# Importing the complete set of features
complete = pd.read_csv('sapso_data.csv')

# Specifying the dependent variable and the potential features
y = pd.Series(data=complete['Target'])
X = complete.drop(columns=['cik','fraud', 'res', 'Target'])

# Split data into train & validation (70 -- 30)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Specifying the numerical columns
num_cols = list(xtrain.select_dtypes(include=['float']).columns)
non_num_cols = list(xtrain.select_dtypes(exclude=['float']).columns)

# Specifying standardizer
scaler = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), num_cols),
        ('non_num', 'passthrough', non_num_cols)
    ])

# Performing standardization based on the train data, and transforming test data
xtrain = scaler.fit_transform(xtrain)
xtest = scaler.transform(xtest)

ytrain = np.asarray(ytrain)
ytest = np.asarray(ytest)

# Adding them to a single fold
fold = {'xt':xtrain, 'yt':ytrain, 'xv':xtest, 'yv':ytest}

# Defining the parameters
k    = 7     # k-value in KNN
N    = 75     # number of particles
T    = 250    # maximum number of iterations
w_start = 0.9    # Inertia weight start value
w_end = 0.4     # Inertia weight end value
c1   = 2.0      # The cognitive coefficient
c2   = 2.0      # The social coefficient
thres = 0.6   # The value for lambda to convert a feature to 0 or 1
lb = 0        # The lower bound of both the velocity and the position 
ub = 1        # The upper bound of both the velocity and the position

# ECM parameters
P_FR = 0.0324         # The percentage of FRs in the population of interest
P_NonFR = (1 - P_FR)  # The percentage of Non-FRs in the population of interest
C_FP = 1              # The cost of a false positive
C_FN = 20             # The cost of a false negative

# Extra parameters for potentially tuning ECM
p_range = np.arange(0.0, 1.0, 0.001) 
n_thresholds = len(p_range)

# Adding the to the optional parameters
opts = {'k':k, 'fold':fold, 'N':N, 'T':T, 'c1':c1, 'c2':c2}

# Dimension
dim = np.size(xtrain, 1)

# Making sure each variable has an upper and lower bound
if np.size(lb) == 1:
    ub = ub * np.ones([1, dim], dtype='float')
    lb = lb * np.ones([1, dim], dtype='float')

# %% [markdown]
# ## Pipelines

# %%
# Pipeline steps
knn_steps = [
    ("over", SMOTE(random_state=42)), 
    ("knn", KNeighborsClassifier(n_neighbors=7, p=2, weights='distance'))
]

# Pipeline
knn_pipeline = Pipeline(knn_steps)

# %%
# Pipeline steps
rlr_steps = [
    ("over", SMOTE(random_state=42)), 
    ("lr", LogisticRegression(random_state=21, solver='lbfgs', max_iter=1000000, 
                              penalty='l2', C=0.00026826957952797245)), 
]

# Pipeline
rlr_pipeline = Pipeline(rlr_steps)

# %%
# Pipeline steps
lgbm_steps = [
    ("over", SMOTE(random_state=42)), 
    ("gb", ltb.LGBMClassifier(random_state=42, n_jobs=-1,
                             learning_rate=0.1, max_depth=5, min_child_samples=100,
                             num_leaves=19, reg_lambda=10)), 
]

# Pipeline
lgbm_pipeline = Pipeline(lgbm_steps)

# %% [markdown]
# ## Defining various functions within PSO

# %% [markdown]
# ### The initalization of position and velocity

# %%
def init_position(lb, ub, N, dim):
    X = np.zeros([N, dim], dtype='float')
    for i in range(N):
        for d in range(dim):
            X[i,d] = lb[0,d] + (ub[0,d] - lb[0,d]) * rand()        
    
    return X

def init_velocity(lb, ub, N, dim):
    V    = np.zeros([N, dim], dtype='float')
    Vmax = np.zeros([1, dim], dtype='float')
    Vmin = np.zeros([1, dim], dtype='float')
    
    # Maximum & minimum velocity
    for d in range(dim):
        Vmax[0,d] = (ub[0,d] - lb[0,d]) / 2
        Vmin[0,d] = -Vmax[0,d]
        
    for i in range(N):
        for d in range(dim):
            V[i,d] = Vmin[0,d] + (Vmax[0,d] - Vmin[0,d]) * rand()
        
    return V, Vmax, Vmin

# %% [markdown]
# ### Boundary check

# %%
def boundary(x, lb, ub):
    for d in range (dim):
        if x[d] < lb[d]:
            x[d] = lb[d]
        if x[d] > ub[d]:
            x[d] = ub[d]
    
    return x

# %% [markdown]
# ### Converting continous values to discrete (Variation for final global best included)

# %%
def binary_conversion(X, thres, dim):
    Xbin = np.zeros([dim], dtype='int')
    for d in range(dim):
        if X[d] > thres:
            Xbin[d] = 1
        else:
            Xbin[d] = 0

    return Xbin

def fin_binary_conversion(X, thres, dim):
    Xbin = np.zeros([dim], dtype='int')
    for d in range(dim):
        if X[d] > thres:
            Xbin[d] = 1
        else:
            Xbin[d] = 0

    return Xbin

# %% [markdown]
# ### ECM

# %%
# Defining a function that will eventually extract the best ECM for the optimal threshold
def ECM(y_test, y_pred):
    fn = np.sum((y_test == 1) & (y_pred == 0))
    fp = np.sum((y_test == 0) & (y_pred == 1))    
    p = np.sum(y_test == 1)
    n = np.sum(y_test == 0)
    
    score = C_FN * P_FR * (fn/p) + C_FP * P_NonFR * (fp/n)
    return score

# %%
rlr_p_range = np.arange(0.45, 0.55, 0.0001) 
rlr_n_thresholds = len(rlr_p_range)

def RLR_ECM(y_test, y_pred_prob):
    ecm_scores = np.zeros(rlr_n_thresholds)
    for i, p in enumerate(rlr_p_range):
        y_pred = np.where(y_pred_prob >= p, 1, 0)
        fn = np.sum((y_test == 1) & (y_pred == 0))
        fp = np.sum((y_test == 0) & (y_pred == 1))
        p = np.sum(y_test == 1)
        n = np.sum(y_test == 0)
        score = C_FN * P_FR * (fn/p) + C_FP * P_NonFR * (fp/(n-p))
        ecm_scores[i] = score
    return np.min(ecm_scores)

# %%
# Defining thresholds and number of thresholds for the tuning of ECM
knn_p_range = np.arange(0.5, 1.0, 0.0005) 
knn_n_thresholds = len(knn_p_range)

# Defining the function for the performance metric in the gridsearch
def KNN_ECM(y_test, y_pred_prob):
    ecm_scores = np.zeros(knn_n_thresholds)
    for i, p in enumerate(knn_p_range):
        y_pred = np.where(y_pred_prob >= p, 1, 0)
        fn = np.sum((y_test == 1) & (y_pred == 0))
        fp = np.sum((y_test == 0) & (y_pred == 1))
        p = np.sum(y_test == 1)
        n = np.sum(y_test == 0)
        score = C_FN * P_FR * (fn/p) + C_FP * P_NonFR * (fp/(n-p))
        ecm_scores[i] = score
    return np.min(ecm_scores)

# %%
# Defining thresholds and number of thresholds for the tuning of ECM
lgbm_p_range = np.arange(0.0, 0.1, 0.0001) 
lgbm_n_thresholds = len(lgbm_p_range)

# Defining the function for the performance metric in the gridsearch
def LGBM_ECM(y_test, y_pred_prob):
    ecm_scores = np.zeros(lgbm_n_thresholds)
    for i, p in enumerate(lgbm_p_range):
        y_pred = np.where(y_pred_prob >= p, 1, 0)
        fn = np.sum((y_test == 1) & (y_pred == 0))
        fp = np.sum((y_test == 0) & (y_pred == 1))
        p = np.sum(y_test == 1)
        n = np.sum(y_test == 0)
        score = C_FN * P_FR * (fn/p) + C_FP * P_NonFR * (fp/(n-p))
        ecm_scores[i] = score
    return np.min(ecm_scores)

# %% [markdown]
# ### The error rate, and fitness evaluation (varies per model)

# %% [markdown]
# #### Logistic Ridge Regression

# %%
def rlr_error_rate(xtrain, ytrain, x, opts):
    # parameters
    k     = opts['k']
    fold  = opts['fold']
    xt    = fold['xt']
    yt    = fold['yt']
    
    convert = 0.6188118

    # Number of instances
    num_train = np.size(xt, 0)
    
    # Define selected features
    xtrain  = xt[:, x == 1]
    ytrain  = yt.reshape(num_train)  # Solve bug
    
    # Using cv folds instead of test set to prevent data leakage
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=25)
    scores = []
    
    # Get scores for each fold
    for train_index, test_index in skf.split(xtrain, ytrain):
        # Specify train and validation for each fold
        x_train, x_val = xtrain[train_index], xtrain[test_index]
        y_train, y_val = ytrain[train_index], ytrain[test_index]
    
        # Training
        mdl     = rlr_pipeline
        mdl.fit(x_train, y_train)
    
        # Prediction
        #ypred   = mdl.predict(x_val)
        ypred_proba = mdl.predict_proba(x_val)[:, 1]
        ecm = RLR_ECM(y_val, ypred_proba)
        #ecm = ECM(yvalid, ypred_proba)

        err = ecm * convert
        scores.append(err)
    
    # Get the average error
    avg_error = sum(scores) / len(scores)
    
    return avg_error

def rlr_Fun(xtrain, ytrain, x, opts, H):
    x = binary_conversion(x, thres, dim)
    # Parameters
    alpha    = 0.975
    beta     = 1 - alpha
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if tuple(x) in H:
        cost = H[tuple(x)]
    else:
        if num_feat == 0:
            cost  = 1
        else:
            # Get error rate
            error = rlr_error_rate(xtrain, ytrain, x, opts)
            # Objective function
            cost  = alpha * error + beta * (num_feat / max_feat)
            H[tuple(x)] = cost
    
    return cost

# %% [markdown]
# #### K-Nearest Neighbors

# %%
def knn_error_rate(xtrain, ytrain, x, opts):
    # parameters
    k     = opts['k']
    fold  = opts['fold']
    xt    = fold['xt']
    yt    = fold['yt']
    
    convert = 0.6188118

    # Number of instances
    num_train = np.size(xt, 0)
    
    # Define selected features
    xtrain  = xt[:, x == 1]
    ytrain  = yt.reshape(num_train)  # Solve bug
    
    # Using cv folds instead of test set to prevent data leakage
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=25)
    scores = []
    
    # Get scores for each fold
    for train_index, test_index in skf.split(xtrain, ytrain):
        # Specify train and validation for each fold
        x_train, x_val = xtrain[train_index], xtrain[test_index]
        y_train, y_val = ytrain[train_index], ytrain[test_index]
    
        # Training
        mdl     = knn_pipeline
        mdl.fit(x_train, y_train)
    
        # Prediction
        #ypred   = mdl.predict(x_val)
        ypred_proba = mdl.predict_proba(x_val)[:, 1]
        ecm = KNN_ECM(y_val, ypred_proba)
        #ecm = ECM(yvalid, ypred_proba)

        err = ecm * convert
        scores.append(err)
    
    # Get the average error
    avg_error = sum(scores) / len(scores)
    
    return avg_error

def knn_Fun(xtrain, ytrain, x, opts, H):
    x = binary_conversion(x, thres, dim)
    # Parameters
    alpha    = 0.975
    beta     = 1 - alpha
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if tuple(x) in H:
        cost = H[tuple(x)]
    else:
        if num_feat == 0:
            cost  = 1
        else:
            # Get error rate
            error = knn_error_rate(xtrain, ytrain, x, opts)
            # Objective function
            cost  = alpha * error + beta * (num_feat / max_feat)
            H[tuple(x)] = cost
    
    return cost

# %% [markdown]
# #### Light GBM

# %%
def lgbm_error_rate(xtrain, ytrain, x, opts):
    # parameters
    k     = opts['k']
    fold  = opts['fold']
    xt    = fold['xt']
    yt    = fold['yt']
    
    convert = 0.6188118

    # Number of instances
    num_train = np.size(xt, 0)
    
    # Define selected features
    xtrain  = xt[:, x == 1]
    ytrain  = yt.reshape(num_train)  # Solve bug
    
    # Using cv folds instead of test set to prevent data leakage
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=25)
    scores = []
    
    # Get scores for each fold
    for train_index, test_index in skf.split(xtrain, ytrain):
        # Specify train and validation for each fold
        x_train, x_val = xtrain[train_index], xtrain[test_index]
        y_train, y_val = ytrain[train_index], ytrain[test_index]
    
        # Training
        mdl     = lgbm_pipeline
        mdl.fit(x_train, y_train)
    
        # Prediction
        #ypred   = mdl.predict(x_val)
        ypred_proba = mdl.predict_proba(x_val)[:, 1]
        ecm = LGBM_ECM(y_val, ypred_proba)
        #ecm = ECM(yvalid, ypred_proba)

        err = ecm * convert
        scores.append(err)
    
    # Get the average error
    avg_error = sum(scores) / len(scores)
    
    return avg_error

def lgbm_Fun(xtrain, ytrain, x, opts, H):
    x = binary_conversion(x, thres, dim)
    # Parameters
    alpha    = 0.975
    beta     = 1 - alpha
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if tuple(x) in H:
        cost = H[tuple(x)]
    else:
        if num_feat == 0:
            cost  = 1
        else:
            # Get error rate
            error = lgbm_error_rate(xtrain, ytrain, x, opts)
            # Objective function
            cost  = alpha * error + beta * (num_feat / max_feat)
            H[tuple(x)] = cost
    
    return cost

# %% [markdown]
# ### Counting the number of features per iteration

# %%
def NumFeat(x):
    x = binary_conversion(x, thres, dim)
    num_feat = np.sum(x == 1)
    return num_feat

# %% [markdown]
# ### Extracting ECM for global best for each iteration (varies per model)

# %% [markdown]
# #### Logistic Ridge Regression

# %%
def rlr_global_error_rate(xtrain, ytrain, x, opts):
    # parameters
    k     = opts['k']
    fold  = opts['fold']
    xt    = fold['xt']
    yt    = fold['yt']
    
    # Number of instances
    num_train = np.size(xt, 0)
    
    # Define selected features
    xtrain  = xt[:, x == 1]
    ytrain  = yt.reshape(num_train)  # Solve bug
    
    # Using cv folds instead of test set to prevent data leakage
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=25)
    scores = []
    
    # Get scores for each fold
    for train_index, test_index in skf.split(xtrain, ytrain):
        # Specify train and validation for each fold
        x_train, x_val = xtrain[train_index], xtrain[test_index]
        y_train, y_val = ytrain[train_index], ytrain[test_index]
    
        # Training
        mdl     = rlr_pipeline
        mdl.fit(x_train, y_train)
    
        # Prediction
        #ypred   = mdl.predict(x_val)
        ypred_proba = mdl.predict_proba(x_val)[:, 1]
        ecm = RLR_ECM(y_val, ypred_proba)
        scores.append(ecm)
    
    # Get the average error
    avg_error = sum(scores) / len(scores)
    
    return avg_error

def rlr_Global_Fun(xtrain, ytrain, x, opts):
    x = binary_conversion(x, thres, dim)
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if num_feat == 0:
        cost  = 1
    else:
        # Get ECM
        cost = rlr_global_error_rate(xtrain, ytrain, x, opts)

    return cost

# %% [markdown]
# #### K-Nearest Neighbors

# %%
def knn_global_error_rate(xtrain, ytrain, x, opts):
    # parameters
    k     = opts['k']
    fold  = opts['fold']
    xt    = fold['xt']
    yt    = fold['yt']
    
    # Number of instances
    num_train = np.size(xt, 0)
    
    # Define selected features
    xtrain  = xt[:, x == 1]
    ytrain  = yt.reshape(num_train)  # Solve bug
    
    # Using cv folds instead of test set to prevent data leakage
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=25)
    scores = []
    
    # Get scores for each fold
    for train_index, test_index in skf.split(xtrain, ytrain):
        # Specify train and validation for each fold
        x_train, x_val = xtrain[train_index], xtrain[test_index]
        y_train, y_val = ytrain[train_index], ytrain[test_index]
    
        # Training
        mdl     = knn_pipeline
        mdl.fit(x_train, y_train)
    
        # Prediction
        ypred_proba = mdl.predict_proba(x_val)[:, 1]
        ecm = KNN_ECM(y_val, ypred_proba)
        scores.append(ecm)
    
    # Get the average error
    avg_error = sum(scores) / len(scores)
    
    return avg_error

def knn_Global_Fun(xtrain, ytrain, x, opts):
    x = binary_conversion(x, thres, dim)
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if num_feat == 0:
        cost  = 1
    else:
        # Get ECM
        cost = knn_global_error_rate(xtrain, ytrain, x, opts)

    return cost

# %% [markdown]
# #### Light GBM

# %%
def lgbm_global_error_rate(xtrain, ytrain, x, opts):
    # parameters
    k     = opts['k']
    fold  = opts['fold']
    xt    = fold['xt']
    yt    = fold['yt']
    
    # Number of instances
    num_train = np.size(xt, 0)
    
    # Define selected features
    xtrain  = xt[:, x == 1]
    ytrain  = yt.reshape(num_train)  # Solve bug
    
    # Using cv folds instead of test set to prevent data leakage
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=25)
    scores = []
    
    # Get scores for each fold
    for train_index, test_index in skf.split(xtrain, ytrain):
        # Specify train and validation for each fold
        x_train, x_val = xtrain[train_index], xtrain[test_index]
        y_train, y_val = ytrain[train_index], ytrain[test_index]
    
        # Training
        mdl     = lgbm_pipeline
        mdl.fit(x_train, y_train)
    
        # Prediction
        ypred_proba = mdl.predict_proba(x_val)[:, 1]
        ecm = LGBM_ECM(y_val, ypred_proba)
        scores.append(ecm)
    
    # Get the average error
    avg_error = sum(scores) / len(scores)
    
    return avg_error

def lgbm_Global_Fun(xtrain, ytrain, x, opts):
    x = binary_conversion(x, thres, dim)
    # Original feature size
    max_feat = len(x)
    # Number of selected features
    num_feat = np.sum(x == 1)
    # Solve if no feature selected
    if num_feat == 0:
        cost  = 1
    else:
        # Get ECM
        cost = lgbm_global_error_rate(xtrain, ytrain, x, opts)

    return cost

# %% [markdown]
# ## SAPSO Algorithms

# %%
def generate_exemplar(Pbestt, Gbestt, fitness, H):
    Ei = [0] * dim  # initialize the potential exemplar

    # randomly select two personal best positions for each dimension of Ei
    for j in range(dim):
        indices = random.sample(range(len(Pbestt)), 2)
        pbesttm = Pbestt[indices[0]]
        pbesttk = Pbestt[indices[1]]
        if fitness(xtrain, ytrain, pbesttm, opts, H) < fitness(xtrain, ytrain, pbesttk, opts, H):
            Ei[j] = pbesttm[j]
        else:
            Ei[j] = pbesttk[j]

    # check if the fitness value of Ei is worse than Gbestt
    if fitness(xtrain, ytrain, Ei, opts, H) < fitness(xtrain, ytrain, Gbestt, opts, H):
        return Ei
    else:
        return Gbestt

def get_one_flip_neighbors(particle):
    particle = binary_conversion(particle, thres, dim)
    neighbors = []
    for i in range(dim):
        if particle[i] == 1:
            neighbor = np.copy(particle)
            neighbor[i] = 0
            neighbors.append(neighbor)
        else:
            neighbor = np.copy(particle)
            neighbor[i] = 1
            neighbors.append(neighbor)
    return neighbors

# %% [markdown]
# ## SAPSO - Varies per model

# %% [markdown]
# #### Ridge Logistic Regression

# %%
def rlr_SAPSO(xtrain, ytrain, opts):
    # Defining empty swarm
    swarm = []
    # Initialize position & velocity
    X             = init_position(lb, ub, N, dim)
    V, Vmax, Vmin = init_velocity(lb, ub, N, dim) 
    # Defining some prerequisites
    fit   = np.zeros([N, 1], dtype='float')
    Xgb   = np.zeros([1, dim], dtype='float')
    fitG  = float('inf')
    best_fitness = float('inf') * np.ones([dim, 1], dtype='float')
    Xpb   = np.zeros([N, dim], dtype='float')
    fitP  = float('inf') * np.ones([N, 1], dtype='float')
    fitness = float('inf') * np.ones([dim, 1], dtype='float')
    curve = np.zeros([1, T], dtype='float')
    ecmG = np.zeros([1, T], dtype='float')
    nft = np.zeros([1, T], dtype='float')
    # Populating swarm
    swarm.append({'position': X, 'velocity': V, 'pbest': Xpb, 'pbest_fitness': fitP})
    # Defining t and C
    t     = 0
    C     = 0
    # Defining empty lists for new columns
    ns_pos = []
    ns_vel= []
    ns_pb = []
    ns_pbf = []
    # Defining H to store all fitness values for subset of features
    H = {}
    # Defining w to decrease the inertia weight linearly between 0.9 and 0.4
    w = 0
    # While termination criteria is not met
    while t < T:
        # Updating inertia weight
        w = w_start - ((w_start - w_end) / T) * t
        # Sum of swarm fitness (t-1)
        swarm_fit1 = swarm[0]['pbest_fitness'].sum()
        # Fitness of all particles
        for i in range(N):
            # Calculate fitness for particle i
            fit[i,0] = rlr_Fun(xtrain, ytrain, swarm[0]['position'][i,:], opts, H)
            # Check whether it returns nan's
            if np.isnan(fit[i,0]):
                print(fit[i,0])
                fit[i,0] = 1
            # If fitness is lower than current best fitness, replace best pos and best fit
            if fit[i,0] < swarm[0]['pbest_fitness'][i,0]:
                swarm[0]['pbest'][i,:]  = swarm[0]['position'][i,:]
                swarm[0]['pbest_fitness'][i,0] = fit[i,0]
            # If fitness is lower than current global fitness, replace global fitness with best part pos and best part fit
            if swarm[0]['pbest_fitness'][i,0] < fitG:
                Xgb[0,:]  = swarm[0]['pbest'][i,:]
                fitG      = swarm[0]['pbest_fitness'][i,0]
                # Print statement for every update
                print('Global Best updated:',round(fitG,6))
        # Get the sum of the swarms fitness (t)
        swarm_fit2 = swarm[0]['pbest_fitness'].sum()                       
        # Define new swarm
        new_swarm = []
        # Storing the values for pbest as these will be removed but are needed for entire loop
        pbest_exemplar = swarm[0]['pbest']
        # While swarm is not empty update particles and populate new swarm
        while swarm[0]['position'].size > 0:
            # Generating the examplar to update velocity
            E = generate_exemplar(pbest_exemplar, Xgb[0,:], rlr_Fun, H)
            # 2 Random numbers between [0,1]
            r1 = rand()
            r2 = rand()
            # Updating velocity
            velocity = w * swarm[0]['velocity'][0] + c1 *r1 * (swarm[0]['pbest'][0] - swarm[0]['position'][0]) + c2 * r2 * (E - swarm[0]['position'][0])
            # Making sure velocity falls within the boundary
            velocity = boundary(velocity, Vmin[0], Vmax[0])
            # Updating position
            position = swarm[0]['position'][0] + velocity
            # Making sure position falls within the boundary
            position = boundary(position, lb[0], ub[0])
            # Adding the particle's new position, velocity, and their previous personal best and pbest fitness to temporary lists 
            ns_pos.append(position)
            ns_vel.append(velocity)
            ns_pb.append(swarm[0]['pbest'][0])
            ns_pbf.append(swarm[0]['pbest_fitness'][0])
            # Removing the particle at place 0, thereby shifting particle at place 1 to place 0 so that loops takes next particle
            swarm[0]['position'] = np.delete(swarm[0]['position'], 0, axis=0)
            swarm[0]['velocity'] = np.delete(swarm[0]['velocity'], 0, axis=0)
            swarm[0]['pbest'] = np.delete(swarm[0]['pbest'], 0, axis=0)
            swarm[0]['pbest_fitness'] = np.delete(swarm[0]['pbest_fitness'], 0, axis=0)
        # If all particles are updates we switch the lists with the new values to arrays
        ns_pos = np.stack(ns_pos, axis=0 )
        ns_vel = np.stack(ns_vel, axis=0 )
        ns_pb = np.stack(ns_pb, axis=0 )
        ns_pbf = np.stack(ns_pbf, axis=0 )
        # We append the new swarm with the new values
        new_swarm.append({'position': ns_pos, 'velocity': ns_vel, 'pbest': ns_pb, 'pbest_fitness': ns_pbf})
        # We replace the old swarm (t-1) with the new swarm (t)
        swarm = new_swarm
        # We empty the temporary storages
        ns_pos = []
        ns_vel= []
        ns_pb = []
        ns_pbf = []

        # We check whether the sum of the fitness of swarm t-1 is the same as swarm t
        if swarm_fit1 == swarm_fit2:
            # If this is the case we incremetn C by 1
            C += 1
            print('Value of C increased to:',C)
        # If the equation is higher than a random generated number we enter the neigborhood search strategy.
        if ((np.exp(C) - 1)/(np.exp(5)-1)) > rand():
            # We first extract the pbest fitness of all particles
            pbest_fitness = swarm[0]['pbest_fitness']
            # We extract the sorted indices
            sorted_indices = pbest_fitness.argsort(axis=0)
            # Using the sorted indices to sort the swarm from best pbest fitness value to worst
            for key in swarm[0].keys():
                swarm[0][key] = swarm[0][key][sorted_indices.ravel()]
            # Print statement to mention that the strategy is being entered 
            print('Entering Neighborhood Search Strategy')
            # Reset the best fitness values of potential neighbors to infinite
            best_fitness = float('inf') * np.ones([dim, 1], dtype='float')
            # The top 10% of the swarm are being used in the strategy
            for q in range(0,int(0.1 * N)):
                # We set the best_neighbor to None
                best_neighbor = None
                # Reset the best fitness values of potential neighbors to infinite
                best_fitness = float('inf') * np.ones([dim, 1], dtype='float')
                for i, neighbor in enumerate(get_one_flip_neighbors(swarm[0]['position'][q])):
                    # We extract the fitness of this neighbor
                    fitness[i,0] = rlr_Fun(xtrain, ytrain, neighbor, opts, H)  
                    # If the fitness is lower than best_fitness than this is a better neighbor and we replace the neighbor
                    if fitness[i,0] < best_fitness[i,0]:
                        best_neighbor = neighbor
                        # We also update the neighbor's fitness
                        best_fitness[i,0] = fitness[i,0]
                # Replace the elements of the worst 10% with found neighbor for each q
                # q: 0 N: 50 -> replace 49, q:1, N: 50, replace 48, etc.
                swarm[0]['position'][N-q-1] = best_neighbor
                swarm[0]['velocity'][N-q-1] = np.zeros(dim)
                swarm[0]['pbest'][N-q-1] = best_neighbor
                swarm[0]['pbest_fitness'][N-q-1][0] = best_fitness[i,0]             
            # Store result of iteration, convergence, ecm, and number of features
            curve[0,t] = fitG.copy()
            ecmG[0,t] = rlr_Global_Fun(xtrain, ytrain, Xgb[0,:], opts)
            nft[0,t] =  NumFeat(Xgb[0,:])
            # Update the current best
            print("Current Global Best:", round(curve[0,t],6))
            print("Current Global Best ECM:", round(ecmG[0,t],4))
            # Set C back to 0 and increment t by 1
            C = 0
            t += 1
            # Update the iteration
            print('End of iteration:',t)
        else:
            # Store result of iteration, convergence, ecm, and number of features
            curve[0,t] = fitG.copy()
            ecmG[0,t] = rlr_Global_Fun(xtrain, ytrain, Xgb[0,:], opts)
            nft[0,t] =  NumFeat(Xgb[0,:])
            # Update the current best
            print("Current Global Best:", round(curve[0,t],6))
            print("Current Global Best ECM:", round(ecmG[0,t],4))
            # increment t by 1
            t += 1
            # Update the iteration
            print('End of iteration:',t)
            
    # Converting the best position to binary
    Gbin       = fin_binary_conversion(Xgb[0,:], thres, dim) 
    # Reshaping it
    Gbin       = Gbin.reshape(dim)
    # The selected features
    pos        = np.asarray(range(0, dim))    
    sel_index  = pos[Gbin == 1]
    # The amount of selected features
    num_feat   = len(sel_index)
    # Create dictionary with all data that is collected
    sapso_data = {'sf': sel_index, 'c': curve, 'nf': num_feat, 'fit': fitG, 'Xgb': Xgb[0,:], 
                  'Gbin': Gbin, 'ecmG': ecmG,'NFt': nft}
    # Return the data
    return sapso_data

# %% [markdown]
# #### K-Nearest Neighbors

# %%
def knn_SAPSO(xtrain, ytrain, opts):
    # Defining empty swarm
    swarm = []
    # Initialize position & velocity
    X             = init_position(lb, ub, N, dim)
    V, Vmax, Vmin = init_velocity(lb, ub, N, dim) 
    # Defining some prerequisites
    fit   = np.zeros([N, 1], dtype='float')
    Xgb   = np.zeros([1, dim], dtype='float')
    fitG  = float('inf')
    best_fitness = float('inf') * np.ones([dim, 1], dtype='float')
    Xpb   = np.zeros([N, dim], dtype='float')
    fitP  = float('inf') * np.ones([N, 1], dtype='float')
    fitness = float('inf') * np.ones([dim, 1], dtype='float')
    curve = np.zeros([1, T], dtype='float')
    ecmG = np.zeros([1, T], dtype='float')
    nft = np.zeros([1, T], dtype='float')
    # Populating swarm
    swarm.append({'position': X, 'velocity': V, 'pbest': Xpb, 'pbest_fitness': fitP})
    # Defining t and C
    t     = 0
    C     = 0
    # Defining empty lists for new columns
    ns_pos = []
    ns_vel= []
    ns_pb = []
    ns_pbf = []
    # Defining H to store all fitness values for subset of features
    H = {}
    # Defining w_adj to decrease the inertia weight linearly between 0.9 and 0.4
    w = 0
    # While termination criteria is not met
    while t < T:
        # Sum of swarm fitness (t-1)
        swarm_fit1 = swarm[0]['pbest_fitness'].sum()
        # Updating inertia weight
        w = w_start - ((w_start - w_end) / T) * t
        # Fitness of all particles
        for i in range(N):
            # Calculate fitness for particle i
            fit[i,0] = knn_Fun(xtrain, ytrain, swarm[0]['position'][i,:], opts, H)
            # Check whether it returns nan's
            if np.isnan(fit[i,0]):
                print(fit[i,0])
                fit[i,0] = 1
            # If fitness is lower than current best fitness, replace best pos and best fit
            if fit[i,0] < swarm[0]['pbest_fitness'][i,0]:
                swarm[0]['pbest'][i,:]  = swarm[0]['position'][i,:]
                swarm[0]['pbest_fitness'][i,0] = fit[i,0]
            # If fitness is lower than current global fitness, replace global fitness with best part pos and best part fit
            if swarm[0]['pbest_fitness'][i,0] < fitG:
                Xgb[0,:]  = swarm[0]['pbest'][i,:]
                fitG      = swarm[0]['pbest_fitness'][i,0]
                # Print statement for every update
                print('Global Best updated:',round(fitG,6))
                
        # Get the sum of the swarms fitness (t)
        swarm_fit2 = swarm[0]['pbest_fitness'].sum()                    
        # Define new swarm
        new_swarm = []
        # Storing the values for pbest as these will be removed but are needed for entire loop
        pbest_exemplar = swarm[0]['pbest']
        # While swarm is not empty update particles and populate new swarm
        while swarm[0]['position'].size > 0:
            # Generating the examplar to update velocity
            E = generate_exemplar(pbest_exemplar, Xgb[0,:], knn_Fun, H)
            # 2 Random numbers between [0,1]
            r1 = rand()
            r2 = rand()
            # Updating velocity
            velocity = w * swarm[0]['velocity'][0] + c1 *r1 * (swarm[0]['pbest'][0] - swarm[0]['position'][0]) + c2 * r2 * (E - swarm[0]['position'][0])
            # Making sure velocity falls within the boundary
            velocity = boundary(velocity, Vmin[0], Vmax[0])
            # Updating position
            position = swarm[0]['position'][0] + velocity
            # Making sure position falls within the boundary
            position = boundary(position, lb[0], ub[0])
            # Adding the particle's new position, velocity, and their previous personal best and pbest fitness to temporary lists 
            ns_pos.append(position)
            ns_vel.append(velocity)
            ns_pb.append(swarm[0]['pbest'][0])
            ns_pbf.append(swarm[0]['pbest_fitness'][0])
            # Removing the particle at place 0, thereby shifting particle at place 1 to place 0 so that loops takes next particle
            swarm[0]['position'] = np.delete(swarm[0]['position'], 0, axis=0)
            swarm[0]['velocity'] = np.delete(swarm[0]['velocity'], 0, axis=0)
            swarm[0]['pbest'] = np.delete(swarm[0]['pbest'], 0, axis=0)
            swarm[0]['pbest_fitness'] = np.delete(swarm[0]['pbest_fitness'], 0, axis=0)
        # If all particles are updates we switch the lists with the new values to arrays
        ns_pos = np.stack(ns_pos, axis=0 )
        ns_vel = np.stack(ns_vel, axis=0 )
        ns_pb = np.stack(ns_pb, axis=0 )
        ns_pbf = np.stack(ns_pbf, axis=0 )
        # We append the new swarm with the new values
        new_swarm.append({'position': ns_pos, 'velocity': ns_vel, 'pbest': ns_pb, 'pbest_fitness': ns_pbf})
        # We replace the old swarm (t-1) with the new swarm (t)
        swarm = new_swarm
        # We empty the temporary storages
        ns_pos = []
        ns_vel= []
        ns_pb = []
        ns_pbf = []

        # We check whether the sum of the fitness of swarm t-1 is the same as swarm t
        if swarm_fit1 == swarm_fit2:
            # If this is the case we incremetn C by 1
            C += 1
            print('Value of C increased to:',C)
        # If the equation is higher than a random generated number we enter the neigborhood search strategy.
        if ((np.exp(C) - 1)/(np.exp(5)-1)) > rand():
            # We first extract the pbest fitness of all particles
            pbest_fitness = swarm[0]['pbest_fitness']
            # We extract the sorted indices
            sorted_indices = pbest_fitness.argsort(axis=0)
            # Using the sorted indices to sort the swarm from best pbest fitness value to worst
            for key in swarm[0].keys():
                swarm[0][key] = swarm[0][key][sorted_indices.ravel()]
            # Print statement to mention that the strategy is being entered 
            print('Entering Neighborhood Search Strategy')
            # The top 10% of the swarm are being used in the strategy
            for q in range(0,int(0.1 * N)):
                # We set the best_neighbor to None
                best_neighbor = None
                # Reset the best fitness values of potential neighbors to infinite
                best_fitness = float('inf') * np.ones([dim, 1], dtype='float')
                for i, neighbor in enumerate(get_one_flip_neighbors(swarm[0]['position'][q])):
                    # We extract the fitness of this neighbor
                    fitness[i,0] = knn_Fun(xtrain, ytrain, neighbor, opts, H)  
                    # If the fitness is lower than best_fitness than this is a better neighbor and we replace the neighbor
                    if fitness[i,0] < best_fitness[i,0]:
                        best_neighbor = neighbor
                        # We also update the neighbor's fitness
                        best_fitness[i,0] = fitness[i,0]
                # Replace the elements of the worst 10% with found neighbor for each q
                # q: 0 N: 50 -> replace 49, q:1, N: 50, replace 48, etc.
                swarm[0]['position'][N-q-1] = best_neighbor
                swarm[0]['velocity'][N-q-1] = np.zeros(dim)
                swarm[0]['pbest'][N-q-1] = best_neighbor
                swarm[0]['pbest_fitness'][N-q-1][0] = best_fitness[i,0]             
            # Store result of iteration, convergence, ecm, and number of features
            curve[0,t] = fitG.copy()
            ecmG[0,t] = knn_Global_Fun(xtrain, ytrain, Xgb[0,:], opts)
            nft[0,t] =  NumFeat(Xgb[0,:])
            # Update the current best
            print("Current Global Best:", round(curve[0,t],6))
            print("Current Global Best ECM:", round(ecmG[0,t],4))
            # Set C back to 0 and increment t by 1
            C = 0
            t += 1
            # Update the iteration
            print('End of iteration:',t)
        else:
            # Store result of iteration, convergence, ecm, and number of features
            curve[0,t] = fitG.copy()
            ecmG[0,t] = knn_Global_Fun(xtrain, ytrain, Xgb[0,:], opts)
            nft[0,t] =  NumFeat(Xgb[0,:])
            # Update the current best
            print("Current Global Best:", round(curve[0,t],6))
            print("Current Global Best ECM:", round(ecmG[0,t],4))
            # increment t by 1
            t += 1
            # Update the iteration
            print('End of iteration:',t)
            
    # Converting the best position to binary
    Gbin       = fin_binary_conversion(Xgb[0,:], thres, dim) 
    # Reshaping it
    Gbin       = Gbin.reshape(dim)
    # The selected features
    pos        = np.asarray(range(0, dim))    
    sel_index  = pos[Gbin == 1]
    # The amount of selected features
    num_feat   = len(sel_index)
    # Create dictionary with all data that is collected
    sapso_data = {'sf': sel_index, 'c': curve, 'nf': num_feat, 'fit': fitG, 'Xgb': Xgb[0,:], 
                  'Gbin': Gbin, 'ecmG': ecmG,'NFt': nft}
    # Return the data
    return sapso_data

# %% [markdown]
# #### Light GBM

# %%
def lgbm_SAPSO(xtrain, ytrain, opts):
    # Defining empty swarm
    swarm = []
    # Initialize position & velocity
    X             = init_position(lb, ub, N, dim)
    V, Vmax, Vmin = init_velocity(lb, ub, N, dim) 
    # Defining some prerequisites
    fit   = np.zeros([N, 1], dtype='float')
    Xgb   = np.zeros([1, dim], dtype='float')
    fitG  = float('inf')
    best_fitness = float('inf') * np.ones([dim, 1], dtype='float')
    Xpb   = np.zeros([N, dim], dtype='float')
    fitP  = float('inf') * np.ones([N, 1], dtype='float')
    fitness = float('inf') * np.ones([dim, 1], dtype='float')
    curve = np.zeros([1, T], dtype='float')
    ecmG = np.zeros([1, T], dtype='float')
    nft = np.zeros([1, T], dtype='float')
    # Populating swarm
    swarm.append({'position': X, 'velocity': V, 'pbest': Xpb, 'pbest_fitness': fitP})
    # Defining t and C
    t     = 0
    C     = 0
    # Defining empty lists for new columns
    ns_pos = []
    ns_vel= []
    ns_pb = []
    ns_pbf = []
    # Defining H to store all fitness values for subset of features
    H = {}
    # Defining w_adj to decrease the inertia weight linearly between 0.9 and 0.4
    w = 0
    # While termination criteria is not met
    while t < T:
        # Sum of swarm fitness (t-1)
        swarm_fit1 = swarm[0]['pbest_fitness'].sum()
        # Updating inertia weight
        w = w_start - ((w_start - w_end) / T) * t
        # Fitness of all particles
        for i in range(N):
            # Calculate fitness for particle i
            fit[i,0] = lgbm_Fun(xtrain, ytrain, swarm[0]['position'][i,:], opts, H)
            # Check whether it returns nan's
            if np.isnan(fit[i,0]):
                print(fit[i,0])
                fit[i,0] = 1
            # If fitness is lower than current best fitness, replace best pos and best fit
            if fit[i,0] < swarm[0]['pbest_fitness'][i,0]:
                swarm[0]['pbest'][i,:]  = swarm[0]['position'][i,:]
                swarm[0]['pbest_fitness'][i,0] = fit[i,0]
            # If fitness is lower than current global fitness, replace global fitness with best part pos and best part fit
            if swarm[0]['pbest_fitness'][i,0] < fitG:
                Xgb[0,:]  = swarm[0]['pbest'][i,:]
                fitG      = swarm[0]['pbest_fitness'][i,0]
                # Print statement for every update
                print('Global Best updated:',round(fitG,6))
        # Get the sum of the swarms fitness (t)
        swarm_fit2 = swarm[0]['pbest_fitness'].sum()                    
        # Define new swarm
        new_swarm = []
        # Storing the values for pbest as these will be removed but are needed for entire loop
        pbest_exemplar = swarm[0]['pbest']
        # While swarm is not empty update particles and populate new swarm
        while swarm[0]['position'].size > 0:
            # Generating the examplar to update velocity
            E = generate_exemplar(pbest_exemplar, Xgb[0,:], lgbm_Fun, H)
            # 2 Random numbers between [0,1]
            r1 = rand()
            r2 = rand()
            # Updating velocity
            velocity = w * swarm[0]['velocity'][0] + c1 *r1 * (swarm[0]['pbest'][0] - swarm[0]['position'][0]) + c2 * r2 * (E - swarm[0]['position'][0])
            # Making sure velocity falls within the boundary
            velocity = boundary(velocity, Vmin[0], Vmax[0])
            # Updating position
            position = swarm[0]['position'][0] + velocity
            # Making sure position falls within the boundary
            position = boundary(position, lb[0], ub[0])
            # Adding the particle's new position, velocity, and their previous personal best and pbest fitness to temporary lists 
            ns_pos.append(position)
            ns_vel.append(velocity)
            ns_pb.append(swarm[0]['pbest'][0])
            ns_pbf.append(swarm[0]['pbest_fitness'][0])
            # Removing the particle at place 0, thereby shifting particle at place 1 to place 0 so that loops takes next particle
            swarm[0]['position'] = np.delete(swarm[0]['position'], 0, axis=0)
            swarm[0]['velocity'] = np.delete(swarm[0]['velocity'], 0, axis=0)
            swarm[0]['pbest'] = np.delete(swarm[0]['pbest'], 0, axis=0)
            swarm[0]['pbest_fitness'] = np.delete(swarm[0]['pbest_fitness'], 0, axis=0)
        # If all particles are updates we switch the lists with the new values to arrays
        ns_pos = np.stack(ns_pos, axis=0 )
        ns_vel = np.stack(ns_vel, axis=0 )
        ns_pb = np.stack(ns_pb, axis=0 )
        ns_pbf = np.stack(ns_pbf, axis=0 )
        # We append the new swarm with the new values
        new_swarm.append({'position': ns_pos, 'velocity': ns_vel, 'pbest': ns_pb, 'pbest_fitness': ns_pbf})
        # We replace the old swarm (t-1) with the new swarm (t)
        swarm = new_swarm
        # We empty the temporary storages
        ns_pos = []
        ns_vel= []
        ns_pb = []
        ns_pbf = []

        # We check whether the sum of the fitness of swarm t-1 is the same as swarm t
        if swarm_fit1 == swarm_fit2:
            # If this is the case we incremetn C by 1
            C += 1
            print('Value of C increased to:',C)
        # If the equation is higher than a random generated number we enter the neigborhood search strategy.
        if ((np.exp(C) - 1)/(np.exp(5)-1)) > rand():
            # We first extract the pbest fitness of all particles
            pbest_fitness = swarm[0]['pbest_fitness']
            # We extract the sorted indices
            sorted_indices = pbest_fitness.argsort(axis=0)
            # Using the sorted indices to sort the swarm from best pbest fitness value to worst
            for key in swarm[0].keys():
                swarm[0][key] = swarm[0][key][sorted_indices.ravel()]
            # Print statement to mention that the strategy is being entered 
            print('Entering Neighborhood Search Strategy')
            # The top 10% of the swarm are being used in the strategy
            for q in range(0,int(0.1 * N)):
                # We set the best_neighbor to None
                best_neighbor = None
                # Reset the best fitness values of potential neighbors to infinite
                best_fitness = float('inf') * np.ones([dim, 1], dtype='float')
                for i, neighbor in enumerate(get_one_flip_neighbors(swarm[0]['position'][q])):
                    # We extract the fitness of this neighbor
                    fitness[i,0] = lgbm_Fun(xtrain, ytrain, neighbor, opts, H)  
                    # If the fitness is lower than best_fitness than this is a better neighbor and we replace the neighbor
                    if fitness[i,0] < best_fitness[i,0]:
                        best_neighbor = neighbor
                        # We also update the neighbor's fitness
                        best_fitness[i,0] = fitness[i,0]
                # Replace the elements of the worst 10% with found neighbor for each q
                # q: 0 N: 50 -> replace 49, q:1, N: 50, replace 48, etc.
                swarm[0]['position'][N-q-1] = best_neighbor
                swarm[0]['velocity'][N-q-1] = np.zeros(dim)
                swarm[0]['pbest'][N-q-1] = best_neighbor
                swarm[0]['pbest_fitness'][N-q-1][0] = best_fitness[i,0]             
            # Store result of iteration, convergence, ecm, and number of features
            curve[0,t] = fitG.copy()
            ecmG[0,t] = lgbm_Global_Fun(xtrain, ytrain, Xgb[0,:], opts)
            nft[0,t] =  NumFeat(Xgb[0,:])
            # Update the current best
            print("Current Global Best:", round(curve[0,t],6))
            print("Current Global Best ECM:", round(ecmG[0,t],4))
            # Set C back to 0 and increment t by 1
            C = 0
            t += 1
            # Update the iteration
            print('End of iteration:',t)
        else:
            # Store result of iteration, convergence, ecm, and number of features
            curve[0,t] = fitG.copy()
            ecmG[0,t] = lgbm_Global_Fun(xtrain, ytrain, Xgb[0,:], opts)
            nft[0,t] =  NumFeat(Xgb[0,:])
            # Update the current best
            print("Current Global Best:", round(curve[0,t],6))
            print("Current Global Best ECM:", round(ecmG[0,t],4))
            # increment t by 1
            t += 1
            # Update the iteration
            print('End of iteration:',t)
            
    # Converting the best position to binary
    Gbin       = fin_binary_conversion(Xgb[0,:], thres, dim) 
    # Reshaping it
    Gbin       = Gbin.reshape(dim)
    # The selected features
    pos        = np.asarray(range(0, dim))    
    sel_index  = pos[Gbin == 1]
    # The amount of selected features
    num_feat   = len(sel_index)
    # Create dictionary with all data that is collected
    sapso_data = {'sf': sel_index, 'c': curve, 'nf': num_feat, 'fit': fitG, 'Xgb': Xgb[0,:], 
                  'Gbin': Gbin, 'ecmG': ecmG,'NFt': nft}
    # Return the data
    return sapso_data

# %% [markdown]
# ## SAPSO - Ridge Logistic Regression

# %% [markdown]
# ### Running SAPSO

# %%
rlr_Results = rlr_SAPSO(xtrain, ytrain, opts)
# Out:
# Global Best updated: 0.301316
# Global Best updated: 0.294373
# Current Global Best: 0.294373
# Current Global Best ECM: 0.4723
# End of iteration: 1
# Global Best updated: 0.294209
# Global Best updated: 0.275385
# Global Best updated: 0.27265
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 2
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 3
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 4
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 5
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 6
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 7
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 8
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 9
# Current Global Best: 0.27265
# Current Global Best ECM: 0.438
# End of iteration: 10
# Global Best updated: 0.272648
# Global Best updated: 0.270795
# Current Global Best: 0.270795
# Current Global Best ECM: 0.4349
# End of iteration: 11
# Current Global Best: 0.270795
# Current Global Best ECM: 0.4349
# End of iteration: 12
# Current Global Best: 0.270795
# Current Global Best ECM: 0.4349
# End of iteration: 13
# Global Best updated: 0.268459
# Current Global Best: 0.268459
# Current Global Best ECM: 0.4303
# End of iteration: 14
# Global Best updated: 0.267275
# Current Global Best: 0.267275
# Current Global Best ECM: 0.4285
# End of iteration: 15
# Global Best updated: 0.26571
np.arange(0, opts['T'], 1.0) + 1.0

fig, ax = plt.subplots()
ax.plot(x, rlr_curve, linestyle='-',color='black')
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('Fitness')
ax.set_title('SAPSO - RLR')
ax.grid()

plt.show()
fig.savefig("rlr_sapso_fitplot.jpg", dpi=300, bbox_inches='tight')

# %%
# ECM and number of features
rlr_ecmG = rlr_Results['ecmG']
rlr_ecmG = rlr_ecmG.reshape(np.size(rlr_ecmG,1))
rlr_nft = rlr_Results['NFt']
rlr_nft = rlr_nft.reshape(np.size(rlr_nft,1))
x = np.arange(0, opts['T'], 1.0) + 1.0

fig, ax = plt.subplots()
ax.plot(x, rlr_ecmG, linestyle='-',color='black', label='ECM')
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('ECM')
ax.set_title('SAPSO - RLR')
ax.grid()

ax2 = ax.twinx()
ax2.plot(x, rlr_nft, linestyle='--',color='black', label='NFT')
ax2.set_ylabel('NFT')
ax2.tick_params(axis='y')

lines = [ax.get_lines()[0], ax2.get_lines()[0]]
ax.legend(lines, [l.get_label() for l in lines], loc='upper right')

plt.show()
fig.savefig("rlr_sapso_plot.jpg", dpi=300, bbox_inches='tight')

# %%
# Number of selected features
rlr_num_feat = rlr_Results['nf']
print("Feature Size:", rlr_num_feat)
# Out:
# Feature Size: 279

# %%
X = complete.drop(columns=['cik','fraud', 'Target', 'res'])
rlr_pso_X = X.columns[rlr_sf]
print(rlr_pso_X)
rlr_pso_data = pd.DataFrame(X, columns = rlr_pso_X)
rlr_pso_data['Target'] = complete['Target']

rlr_pso_data.to_csv('rlr_sapso_data.csv',index=False)
# Out:
# Index(['ARtS', 'ARtTA', 'AFDAtAR', 'AFDAtNS', 'Zscore', 'cItS', 'DtE', 'DfF',
#        'PA', 'PPEtTA',
#        ...
#        'SIC_8011.0', 'SIC_8051.0', 'SIC_8062.0', 'SIC_8071.0', 'SIC_8090.0',
#        'SIC_8093.0', 'SIC_8711.0', 'SIC_8741.0', 'SIC_8742.0', 'SIC_9995.0'],
#       dtype='object', length=279)

# %% [markdown]
# ## SAPSO - K-Nearest Neighbors

# %% [markdown]
# ### Running SAPSO

# %%
knn_Results = knn_SAPSO(xtrain, ytrain, opts)
# Out:
# Global Best updated: 0.30012
# Global Best updated: 0.279875
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 1
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 2
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 3
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 4
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 5
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 6
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 7
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 8
# Current Global Best: 0.279875
# Current Global Best ECM: 0.4484
# End of iteration: 9
# Global Best updated: 0.278769
# Current Global Best: 0.278769
# Current Global Best ECM: 0.4465
# End of iteration: 10
# Current Global Best: 0.278769
# Current Global Best ECM: 0.4465
# End of iteration: 11
# Current Global Best: 0.278769
# Current Global Best ECM: 0.4465
# End of iteration: 12
# Global Best updated: 0.27572
# Current Global Best: 0.27572
# Current Global Best ECM: 0.4397
# End of iteration: 13
# Global Best updated: 0.255087
# Current Global Best: 0.255087
# Current Global Best ECM: 0.4058
# End of iteration: 14
# Current Global Best: 0.255087
# Current Global Best ECM: 0.4058
# End of iteration: 15
# Current Global Best: 0.255087
# Current Global Best ECM: 0.4058
# End of iteration: 16
# Current Global Best: 0.255087
# Current Global Best ECM: 0.4058
# End of iteration: 17
# Current Global Best: 0.255087
# Current Global Best ECM: 0.4058
# End of iteration: 18
# Current Global Best: 0.255087
# Current Global Best ECM: 0.4058
# End of iteration:
# Value of C increased to: 3
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 223
# Value of C increased to: 4
# Entering Neighborhood Search Strategy
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 224
# Value of C increased to: 1
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 225
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 226
# Value of C increased to: 2
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 227
# Value of C increased to: 3
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 228
# Value of C increased to: 4
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 229
# Value of C increased to: 5
# Entering Neighborhood Search Strategy
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 230
# Value of C increased to: 1
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 231
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 232
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 233
# Value of C increased to: 2
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 234
# Value of C increased to: 3
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 235
# Value of C increased to: 4
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 236
# Value of C increased to: 5
# Entering Neighborhood Search Strategy
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 237
# Value of C increased to: 1
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 238
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 239
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 240
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 241
# Value of C increased to: 2
# Entering Neighborhood Search Strategy
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 242
# Value of C increased to: 1
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 243
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 244
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 245
# Value of C increased to: 2
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 246
# Value of C increased to: 3
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 247
# Value of C increased to: 4
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 248
# Value of C increased to: 5
# Entering Neighborhood Search Strategy
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 249
# Value of C increased to: 1
# Current Global Best: 0.231465
# Current Global Best ECM: 0.3668
# End of iteration: 250

# %%
# plot convergence
knn_sf   = knn_Results['sf']
knn_curve   = knn_Results['c']
knn_curve   = knn_curve.reshape(np.size(knn_curve,1))
x       = np.arange(0, opts['T'], 1.0) + 1.0

fig, ax = plt.subplots()
ax.plot(x, knn_curve, linestyle='-',color='black')
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('Fitness')
ax.set_title('SAPSO - KNN')
ax.grid()

plt.show()
fig.savefig("knn_sapso_fitplot.jpg", dpi=300, bbox_inches='tight')

# %%
# ECM and number of features
knn_ecmG = knn_Results['ecmG']
knn_ecmG = knn_ecmG.reshape(np.size(knn_ecmG,1))
knn_nft = knn_Results['NFt']
knn_nft = knn_nft.reshape(np.size(knn_nft,1))
x = np.arange(0, opts['T'], 1.0) + 1.0

fig, ax = plt.subplots()
ax.plot(x, knn_ecmG, linestyle='-',color='black', label='ECM')
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('ECM')
ax.set_title('SAPSO - KNN')
ax.grid()

ax2 = ax.twinx()
ax2.plot(x, knn_nft, linestyle='--',color='black', label='NFT')
ax2.set_ylabel('NFT')
ax2.tick_params(axis='y')

lines = [ax.get_lines()[0], ax2.get_lines()[0]]
ax.legend(lines, [l.get_label() for l in lines], loc='upper right')

plt.show()
fig.savefig("knn_sapso_plot.jpg", dpi=300, bbox_inches='tight')

# %%
# Number of selected features
knn_num_feat = knn_Results['nf']
print("Feature Size:", knn_num_feat)
# Out:
# Feature Size: 260

# %%
X = complete.drop(columns=['cik','fraud','Target', 'res'])
knn_pso_X = X.columns[knn_sf]
print(knn_pso_X)
knn_pso_data = pd.DataFrame(X, columns = knn_pso_X)
knn_pso_data['Target'] = complete['Target']

knn_pso_data.to_csv('knn_sapso_data.csv',index=False)
# Out:
# Index(['DtE', 'DfF', 'GM', 'cROE', 'ROAtTA', 'PPEtTA', 'StTA', 'UEP', 'IoGMP',
#        'NewS',
#        ...
#        'SIC_7381.0', 'SIC_7389.0', 'SIC_7510.0', 'SIC_7841.0', 'SIC_7900.0',
#        'SIC_8011.0', 'SIC_8093.0', 'SIC_8300.0', 'SIC_8711.0', 'SIC_9995.0'],
#       dtype='object', length=260)

# %% [markdown]
# ## SAPSO - Light GBM

# %% [markdown]
# First, create new x_train and y_train without standardization

# %%
# Importing the complete set of features
complete = pd.read_csv('sapso_data.csv')

# Specifying the dependent variable and the potential features
y = pd.Series(data=complete['Target'])
X = complete.drop(columns=['cik','fraud', 'res', 'Target'])

# Split data into train & validation (70 -- 30)
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Specifying the numerical columns
num_cols = list(xtrain.select_dtypes(include=['float']).columns)
non_num_cols = list(xtrain.select_dtypes(exclude=['float']).columns)

# Transforming to arrays
ytrain = np.asarray(ytrain)
ytest = np.asarray(ytest)
xtrain = np.asarray(xtrain)
xtest = np.asarray(xtest)

# Adding them to a single fold
fold = {'xt':xtrain, 'yt':ytrain, 'xv':xtest, 'yv':ytest}

# Adding the to the optional parameters
opts = {'k':k, 'fold':fold, 'N':N, 'T':T, 'c1':c1, 'c2':c2}

# Dimension
dim = np.size(xtrain, 1)

# Making sure each variable has an upper and lower bound
if np.size(lb) == 1:
    ub = ub * np.ones([1, dim], dtype='float')
    lb = lb * np.ones([1, dim], dtype='float')

# %% [markdown]
# ### Running SAPSO

# %%
lgbm_Results = lgbm_SAPSO(xtrain, ytrain, opts)
# Out:
# Global Best updated: 0.340447
# Global Best updated: 0.333848
# Global Best updated: 0.316031
# Global Best updated: 0.309492
# Global Best updated: 0.296651
# Global Best updated: 0.296003
# Global Best updated: 0.290443
# Global Best updated: 0.28427
# Current Global Best: 0.28427
# Current Global Best ECM: 0.4548
# End of iteration: 1
# Current Global Best: 0.28427
# Current Global Best ECM: 0.4548
# End of iteration: 2
# Global Best updated: 0.281626
# Current Global Best: 0.281626
# Current Global Best ECM: 0.4506
# End of iteration: 3
# Global Best updated: 0.263747
# Current Global Best: 0.263747
# Current Global Best ECM: 0.4199
# End of iteration: 4
# Current Global Best: 0.263747
# Current Global Best ECM: 0.4199
# End of iteration: 5
# Current Global Best: 0.263747
# Current Global Best ECM: 0.4199
# End of iteration: 6
# Current Global Best: 0.263747
# Current Global Best ECM: 0.4199
# End of iteration: 7
# Current Global Best: 0.263747
# Current Global Best ECM: 0.4199
# End of iteration: 8
# Global Best updated: 0.263708

# %%
# plot convergence
lgbm_sf   = lgbm_Results['sf']
lgbm_curve   = lgbm_Results['c']
lgbm_curve   = lgbm_curve.reshape(np.size(lgbm_curve,1))
x       = np.arange(0, opts['T'], 1.0) + 1.0

fig, ax = plt.subplots()
ax.plot(x, lgbm_curve, linestyle='-',color='black')
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('Fitness')
ax.set_title('SAPSO - LGBM')
ax.grid()

plt.show()
fig.savefig("lgbm_sapso_fitplot.jpg", dpi=300, bbox_inches='tight')

# %%
# ECM and number of features
lgbm_ecmG = lgbm_Results['ecmG']
lgbm_ecmG = lgbm_ecmG.reshape(np.size(lgbm_ecmG,1))
lgbm_nft = lgbm_Results['NFt']
lgbm_nft = lgbm_nft.reshape(np.size(lgbm_nft,1))
x = np.arange(0, opts['T'], 1.0) + 1.0

fig, ax = plt.subplots()
ax.plot(x, lgbm_ecmG, linestyle='-',color='black', label='ECM')
ax.set_xlabel('Number of Iterations')
ax.set_ylabel('ECM')
ax.set_title('SAPSO - LGBM')
ax.grid()

ax2 = ax.twinx()
ax2.plot(x, lgbm_nft, linestyle='--',color='black', label='NFT')
ax2.set_ylabel('NFT')
ax2.tick_params(axis='y')

lines = [ax.get_lines()[0], ax2.get_lines()[0]]
ax.legend(lines, [l.get_label() for l in lines], loc='upper right')

plt.show()
fig.savefig("lgbm_sapso_plot.jpg", dpi=300, bbox_inches='tight')

# %%
# Number of selected features
lgbm_num_feat = lgbm_Results['nf']
print("Feature Size:", lgbm_num_feat)

# %%
X = complete.drop(columns=['cik','fraud', 'Target', 'res'])
lgbm_pso_X = X.columns[lgbm_sf]
print(lgbm_pso_X)
lgbm_pso_data = pd.DataFrame(X, columns = lgbm_pso_X)
lgbm_pso_data['Target'] = complete['Target']

lgbm_pso_data.to_csv('lgbm_sapso_data.csv',index=False)
