# %%
import pandas as pd
import numpy as np
import textstat as ts
import nltk
#nltk.download('punkt')
from nltk.tokenize import word_tokenize
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# ## Importing and merging Text Data

# %%
tran = pd.read_csv('tran_read_data.csv')
mda = pd.read_csv('mda_read_data.csv')

# %%
tran = tran.drop(columns=['Unnamed: 0'])

# %%
df = pd.merge(tran,mda, on=['year','cik'])

# %%
print(len(df))
df = df[~df.isnull().any(axis=1)]
print(len(df))
# Out:
# 5794
# 5788

# %% [markdown]
# ## Calculate FOG Index

# %%
def calculate_fog(text):
    return ts.gunning_fog(text)

# %%
df['FOG_MDA'] = df['mda'].apply(calculate_fog)
df['FOG_Q1'] = df['transcript_qQ1'].apply(calculate_fog)
df['FOG_Q2'] = df['transcript_qQ2'].apply(calculate_fog)
df['FOG_Q3'] = df['transcript_qQ3'].apply(calculate_fog)
df['FOG_Q4'] = df['transcript_qQ4'].apply(calculate_fog)
df
# Out:
#             cik  year                                     transcript_qQ1  \
# 0        1800.0  2008  Well, it’s certainly a key strategic priority....
# 1        1800.0  2010  Thanks Tom. This morning I will review the per...
# 2        1800.0  2011  No, they're shared R&D on that program. Rick, ...
# 3        1800.0  2012  Yes, that's probably around right. That's prob...
# 4        1800.0  2013  Well, in the U.S., first of all, I would say i...
# ...         ...   ...                                                ...
# 5789  1561627.0  2013  Thank you, Melissa, and good morning, everyone...
# 5790  1564822.0  2013  I think  when we think about M&A, we think abo...
# 5791  1564902.0  2013  Thanks, Gene, and thank you to everyone on the...
# 5792  1569134.0  2013  Okay. So by my count, we've now told you a cou...
# 5793  1575571.0  2013  Yes. Yeah. Things have picked up a bit in the ...
#
#                                          transcript_qQ2  \
# 0     Yes. I’ll let John take that question Phil. Su...
# 1     No, in my remarks, I said that we would be res...
# 2     I don't have that at my fingertips here, Jami....
# 3     Good morning, and thanks for joining us. Also ...
# 4     Well, thank you and thank you all for your que...
# ...                                                 ...
# 5789  Thank you, Manny, and good morning, everyone. ...
# 5790  No, I think there's probably less potential fo...
# 5791  Thanks, Jim, and good afternoon, everyone. Bef...
# 5792  Thank you, Jennifer. Good afternoon, everyone....
# 5793  Yeah, from acquired TV stations in the second ...
#
#                                          transcript_qQ3  \
# 0     Good morning. Certainly, I think that's possib...
# 1     Yes, Mike you had basically the same question....
# 2     You're right about overall by the internationa...
# 3     Thanks, Miles. Today, we reported ongoing dilu...
# 4     Okay. Thanks, Brian. Good morning. This mornin...
# ...                                                 ...
# 5789  Yes. We are also focusing on some of the carbo...
# 5790  We absolute do. We have been updating  but eve...
# 5791  Thanks, Kelsey. Good afternoon, everyone, and ...
# 5792  Thanks, and good afternoon. As David mentioned...
# 5793  Thank you, Denise and welcome to our third qua...
#
#                                          transcript_qQ4  \
# 0     Yes, we went through a fairly rigorous self-ev...
# 1     Okay. I think you said that Piramal was around...
# 2     Thanks, Miles. We're very pleased at how we en...
# 3     Thanks, Miles. Before I review our financial p...
# 4     Okay. Thanks, Brian, good morning. This mornin...
# ...                                                 ...
# 5789  Thanks, David, and good morning, everyone. I'm...
# 5790  Sure. Our long-term target is to grow in line ...
# 5791  So I'll ask Jim Heaney to comment a little bit...
# 5792  But having said that to the extend that we jus...
# 5793  Thank you, Denise. Good morning, everyone, and...
#
#                                                     mda  FOG_MDA  FOG_Q1  \
# 0     Financial Review Abbotts revenues are derived ...    13.20   12.52
# 1     Financial Review Abbotts revenues are derived ...    13.47   13.95
# 2     Financial Review Abbotts revenues are derived ...    13.63   10.46
# 3     Financial Review Abbotts revenues are derived ...    13.87    9.78
# 4     Financial Review Abbotts revenues are derived ...    13.56    9.48
# ...                                                 ...      ...     ...
# 5789  dollars in thousands, except per share amounts...    14.06    9.96
# 5790  included elsewhere in this Form 10 K.($ in mil...    17.77   12.51
# 5791  The following discussion contains managements ...    16.18   10.50
# 5792  Liquidity and Capital Resources Overview Initi...    17.60    8.53
# 5793  Executive SummaryWe own, operate or service 43...    19.47   15.55
#
#       FOG_Q2  FOG_Q3  FOG_Q4
# 0      14.74   11.80  209.76
# 1      10.23   15.42   10.84
# 2       9.91   10.16   10.48
# 3      12.73   12.39    9.57
# 4       9.50   10.43   11.71
# ...      ...     ...     ...
# 5789   10.17   11.32    9.60
# 5790   11.15   11.86   11.61
# 5791   10.37   10.22   10.98
# 5792   14.64   12.94   13.88
# 5793   12.33   11.72   12.06
#
# [5788 rows x 12 columns]

# %%
df[['FOG_MDA','FOG_Q1','FOG_Q2','FOG_Q3','FOG_Q4']].describe()
# Out:
#            FOG_MDA       FOG_Q1       FOG_Q2       FOG_Q3       FOG_Q4
# count  5788.000000  5788.000000  5788.000000  5788.000000  5788.000000
# mean     15.203730    15.487617    14.319660    14.115976    14.269286
# std       8.917358    17.156485    15.081804    16.748772    15.331169
# min      10.990000     7.190000     7.030000     7.330000     7.100000
# 25%      13.670000    10.587500    10.570000    10.510000    10.430000
# 50%      14.580000    11.810000    11.650000    11.530000    11.410000
# 75%      15.790000    13.640000    13.290000    12.940000    12.880000
# max     453.650000   382.590000   409.290000   586.360000   316.360000

# %% [markdown]
# The FOG index generates a grade level between 0 and 20.
#
# There seem to be a number of observations that score too high on the FOG index, this indicates some sort of fault in the data. It will be decided later on how to adress these faulty scores. For example setting these to the mean.

# %%
print(len(df[df['FOG_MDA'] > 20]))
print(len(df[df['FOG_Q1'] > 20]))
print(len(df[df['FOG_Q2'] > 20]))
print(len(df[df['FOG_Q3'] > 20]))
print(len(df[df['FOG_Q4'] > 20]))
# Out:
# 129
# 363
# 243
# 216
# 238

# %%
mask1 = df['FOG_MDA'] > 20
mask2 = df['FOG_Q1'] > 20
mask3 = df['FOG_Q2'] > 20
mask4 = df['FOG_Q3'] > 20
mask5 = df['FOG_Q4'] > 20

df.loc[mask1, 'FOG_MDA'] = 20
df.loc[mask2, 'FOG_Q1'] = 20
df.loc[mask3, 'FOG_Q2'] = 20
df.loc[mask4, 'FOG_Q3'] = 20
df.loc[mask5, 'FOG_Q4'] = 20

# %%
df[['FOG_MDA','FOG_Q1','FOG_Q2','FOG_Q3','FOG_Q4']].describe()
# Out:
#            FOG_MDA       FOG_Q1       FOG_Q2       FOG_Q3       FOG_Q4
# count  5788.000000  5788.000000  5788.000000  5788.000000  5788.000000
# mean     14.922538    12.538709    12.276501    12.077241    12.039986
# std       1.734926     2.792045     2.545646     2.403117     2.499313
# min      10.990000     7.190000     7.030000     7.330000     7.100000
# 25%      13.670000    10.587500    10.570000    10.510000    10.430000
# 50%      14.580000    11.810000    11.650000    11.530000    11.410000
# 75%      15.790000    13.640000    13.290000    12.940000    12.880000
# max      20.000000    20.000000    20.000000    20.000000    20.000000

# %% [markdown]
# ## Calculate Length (# Words)

# %%
def count_words(text):
    tokens = nltk.word_tokenize(text)
    return len(tokens)

# %%
df['Length_MDA'] = df['mda'].apply(count_words)
df['Length_Q1'] = df['transcript_qQ1'].apply(count_words)
df['Length_Q2'] = df['transcript_qQ2'].apply(count_words)
df['Length_Q3'] = df['transcript_qQ3'].apply(count_words)
df['Length_Q4'] = df['transcript_qQ4'].apply(count_words)
df
# Out:
#             cik  year                                     transcript_qQ1  \
# 0        1800.0  2008  Well, it’s certainly a key strategic priority....
# 1        1800.0  2010  Thanks Tom. This morning I will review the per...
# 2        1800.0  2011  No, they're shared R&D on that program. Rick, ...
# 3        1800.0  2012  Yes, that's probably around right. That's prob...
# 4        1800.0  2013  Well, in the U.S., first of all, I would say i...
# ...         ...   ...                                                ...
# 5789  1561627.0  2013  Thank you, Melissa, and good morning, everyone...
# 5790  1564822.0  2013  I think  when we think about M&A, we think abo...
# 5791  1564902.0  2013  Thanks, Gene, and thank you to everyone on the...
# 5792  1569134.0  2013  Okay. So by my count, we've now told you a cou...
# 5793  1575571.0  2013  Yes. Yeah. Things have picked up a bit in the ...
#
#                                          transcript_qQ2  \
# 0     Yes. I’ll let John take that question Phil. Su...
# 1     No, in my remarks, I said that we would be res...
# 2     I don't have that at my fingertips here, Jami....
# 3     Good morning, and thanks for joining us. Also ...
# 4     Well, thank you and thank you all for your que...
# ...                                                 ...
# 5789  Thank you, Manny, and good morning, everyone. ...
# 5790  No, I think there's probably less potential fo...
# 5791  Thanks, Jim, and good afternoon, everyone. Bef...
# 5792  Thank you, Jennifer. Good afternoon, everyone....
# 5793  Yeah, from acquired TV stations in the second ...
#
#                                          transcript_qQ3  \
# 0     Good morning. Certainly, I think that's possib...
# 1     Yes, Mike you had basically the same question....
# 2     You're right about overall by the internationa...
# 3     Thanks, Miles. Today, we reported ongoing dilu...
# 4     Okay. Thanks, Brian. Good morning. This mornin...
# ...                                                 ...
# 5789  Yes. We are also focusing on some of the carbo...
# 5790  We absolute do. We have been updating  but eve...
# 5791  Thanks, Kelsey. Good afternoon, everyone, and ...
# 5792  Thanks, and good afternoon. As David mentioned...
# 5793  Thank you, Denise and welcome to our third qua...
#
#                                          transcript_qQ4  \
# 0     Yes, we went through a fairly rigorous self-ev...
# 1     Okay. I think you said that Piramal was around...
# 2     Thanks, Miles. We're very pleased at how we en...
# 3     Thanks, Miles. Before I review our financial p...
# 4     Okay. Thanks, Brian, good morning. This mornin...
# ...                                                 ...
# 5789  Thanks, David, and good morning, everyone. I'm...
# 5790  Sure. Our long-term target is to grow in line ...
# 5791  So I'll ask Jim Heaney to comment a little bit...
# 5792  But having said that to the extend that we jus...
# 5793  Thank you, Denise. Good morning, everyone, and...
#
#                                                     mda  FOG_MDA  FOG_Q1  \
# 0     Financial Review Abbotts revenues are derived ...    13.20   12.52
# 1     Financial Review Abbotts revenues are derived ...    13.47   13.95
# 2     Financial Review Abbotts revenues are derived ...    13.63   10.46
# 3     Financial Review Abbotts revenues are derived ...    13.87    9.78
# 4     Financial Review Abbotts revenues are derived ...    13.56    9.48
# ...                                                 ...      ...     ...
# 5789  dollars in thousands, except per share amounts...    14.06    9.96
# 5790  included elsewhere in this Form 10 K.($ in mil...    17.77   12.51
# 5791  The following discussion contains managements ...    16.18   10.50
# 5792  Liquidity and Capital Resources Overview Initi...    17.60    8.53
# 5793  Executive SummaryWe own, operate or service 43...    19.47   15.55
#
#       FOG_Q2  FOG_Q3  FOG_Q4  Length_MDA  Length_Q1  Length_Q2  Length_Q3  \
# 0      14.74   11.80   20.00       10407       8971       9949       8877
# 1      10.23   15.42   10.84       12934      10250       8910       9860
# 2       9.91   10.16   10.48       16226       9262       8435      12882
# 3      12.73   12.39    9.57       14833       8862      10139      16087
# 4       9.50   10.43   11.71       12528      10853      12244      12293
# ...      ...     ...     ...         ...        ...        ...        ...
# 5789   10.17   11.32    9.60       11146       9461       8888       7620
# 5790   11.15   11.86   11.61       21029       7761      13910       8249
# 5791   10.37   10.22   10.98       11786       5867       7906       7274
# 5792   14.64   12.94   13.88        4254       4869       3751       4693
# 5793   12.33   11.72   12.06       13770       4187       3901       5658
#
#       Length_Q4
# 0          7703
# 1         13648
# 2         10732
# 3         12548
# 4         11382
# ...         ...
# 5789      11507
# 5790      20266
# 5791       6633
# 5792       4575
# 5793       8676
#
# [5788 rows x 17 columns]

# %%
df[['Length_MDA','Length_Q1','Length_Q2','Length_Q3','Length_Q4']].describe()
# Out:
#           Length_MDA     Length_Q1     Length_Q2     Length_Q3     Length_Q4
# count    5788.000000   5788.000000   5788.000000   5788.000000   5788.000000
# mean    15773.333967   6147.081721   6455.010021   6730.585867   6828.710781
# std      9745.249309   2372.624522   2423.806186   2722.509753   2566.081584
# min       277.000000    962.000000    998.000000   1235.000000   1013.000000
# 25%      9888.750000   4460.750000   4767.500000   4880.750000   5085.500000
# 50%     13467.000000   6014.500000   6329.500000   6538.000000   6687.500000
# 75%     18860.250000   7615.250000   7912.000000   8152.000000   8237.000000
# max    107700.000000  30903.000000  26404.000000  35326.000000  30518.000000

# %% [markdown]
# ## Exporting the Features

# %%
df_fin = df.drop(columns=['transcript_qQ1','transcript_qQ2','transcript_qQ3','transcript_qQ4','mda'])
df_fin.to_csv('read_features.csv', index=False)

# %%
df_fin.describe()
# Out:
#                 cik         year      FOG_MDA       FOG_Q1       FOG_Q2  \
# count  5.788000e+03  5788.000000  5788.000000  5788.000000  5788.000000
# mean   8.981043e+05  2010.943849    14.922538    12.538709    12.276501
# std    4.251615e+05     1.609478     1.734926     2.792045     2.545646
# min    1.800000e+03  2008.000000    10.990000     7.190000     7.030000
# 25%    8.052640e+05  2010.000000    13.670000    10.587500    10.570000
# 50%    1.013857e+06  2011.000000    14.580000    11.810000    11.650000
# 75%    1.158871e+06  2012.000000    15.790000    13.640000    13.290000
# max    1.575571e+06  2013.000000    20.000000    20.000000    20.000000
#
#             FOG_Q3       FOG_Q4     Length_MDA     Length_Q1     Length_Q2  \
# count  5788.000000  5788.000000    5788.000000   5788.000000   5788.000000
# mean     12.077241    12.039986   15773.333967   6147.081721   6455.010021
# std       2.403117     2.499313    9745.249309   2372.624522   2423.806186
# min       7.330000     7.100000     277.000000    962.000000    998.000000
# 25%      10.510000    10.430000    9888.750000   4460.750000   4767.500000
# 50%      11.530000    11.410000   13467.000000   6014.500000   6329.500000
# 75%      12.940000    12.880000   18860.250000   7615.250000   7912.000000
# max      20.000000    20.000000  107700.000000  30903.000000  26404.000000
#
#           Length_Q3     Length_Q4
# count   5788.000000   5788.000000
# mean    6730.585867   6828.710781
# std     2722.509753   2566.081584
# min     1235.000000   1013.000000
# 25%     4880.750000   5085.500000
# 50%     6538.000000   6687.500000
# 75%     8152.000000   8237.000000
# max    35326.000000  30518.000000
