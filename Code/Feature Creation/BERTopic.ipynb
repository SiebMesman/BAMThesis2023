# %%
import pandas as pd
import time
import re
import nltk
import gensim
import gensim.corpora as corpora
import numpy as np
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from umap import UMAP
from hdbscan import HDBSCAN
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from bertopic.vectorizers import ClassTfidfTransformer
from gensim.models.coherencemodel import CoherenceModel
from collections import Counter

# %% [markdown]
# ## Reading the Data

# %%
tran = pd.read_csv("tran_sent_data.csv")
mda = pd.read_csv('mda_sent_data.csv')

# %%
tran = tran.drop(columns=['Unnamed: 0'])
mda = mda.drop(columns=['Unnamed: 0'])

# %%
df = pd.merge(tran,mda, on=['year','cik'])
df = df.reset_index(drop=True)
print(len(df))
print(len(df.dropna()))
# Out:
# 5794
# 5788

# %%
print(len(df))
df = df[~df.isnull().any(axis=1)]
print(len(df))
# Out:
# 5794
# 5788

# %% [markdown]
# ## Formatting the Text

# %%
# Creation of a function to put the values in the right format
def remove_chars(s):
    s = s.replace('[', '').replace(']','')
    s = s.replace("'",'')
    s = s.replace(',','')
    return s

df['transcript_qQ1'] = df['transcript_qQ1'].apply(remove_chars)
df['transcript_qQ2'] = df['transcript_qQ2'].apply(remove_chars)
df['transcript_qQ3'] = df['transcript_qQ3'].apply(remove_chars)
df['transcript_qQ4'] = df['transcript_qQ4'].apply(remove_chars)
df['mda'] = df['mda'].apply(remove_chars)

# %% [markdown]
# I will remove words that occur only once, add bigrams to docs, (that appear at least 50 times), and filter out words that occur in less than 50 of the documents and words that appear in 50% of the documens

# %%
df['mda'] = df['mda'].apply(lambda x: x.split())

# count the frequency of each word
word_freq = Counter(word for words in df['mda'] for word in words)

# filter out words that appear only once
word_freq = {word: freq for word, freq in word_freq.items() if freq > 1}

# get the count of rows that each word appears in
word_rows = {}
for i, words in df['mda'].iteritems():
    for word in set(words):
        if word in word_freq and not word.isdigit():
            word_rows[word] = word_rows.get(word, set())
            word_rows[word].add(i)

# filter out words that appear in less than 50 rows or in more than 50% of the rows
min_rows = 50
max_rows = len(df) / 2
remaining_words = set(word for word, rows in word_rows.items() if len(rows) >= min_rows and len(rows) <= max_rows)

# join the remaining words into a single string for each row
df['mda'] = df['mda'].apply(lambda x: ' '.join(word for word in x if word in remaining_words))

# %%
df['transcript_qQ1'] = df['transcript_qQ1'].apply(lambda x: x.split())

# count the frequency of each word
word_freq = Counter(word for words in df['transcript_qQ1'] for word in words)

# filter out words that appear only once
word_freq = {word: freq for word, freq in word_freq.items() if freq > 1}

# get the count of rows that each word appears in
word_rows = {}
for i, words in df['transcript_qQ1'].iteritems():
    for word in set(words):
        if word in word_freq and not word.isdigit():
            word_rows[word] = word_rows.get(word, set())
            word_rows[word].add(i)

# filter out words that appear in less than 50 rows or in more than 50% of the rows
min_rows = 50
max_rows = len(df) / 2
remaining_words = set(word for word, rows in word_rows.items() if len(rows) >= min_rows and len(rows) <= max_rows)

# join the remaining words into a single string for each row
df['transcript_qQ1'] = df['transcript_qQ1'].apply(lambda x: ' '.join(word for word in x if word in remaining_words))

# %%
df['transcript_qQ2'] = df['transcript_qQ2'].apply(lambda x: x.split())

# count the frequency of each word
word_freq = Counter(word for words in df['transcript_qQ2'] for word in words)

# filter out words that appear only once
word_freq = {word: freq for word, freq in word_freq.items() if freq > 1}

# get the count of rows that each word appears in
word_rows = {}
for i, words in df['transcript_qQ2'].iteritems():
    for word in set(words):
        if word in word_freq and not word.isdigit():
            word_rows[word] = word_rows.get(word, set())
            word_rows[word].add(i)

# filter out words that appear in less than 50 rows or in more than 50% of the rows
min_rows = 50
max_rows = len(df) / 2
remaining_words = set(word for word, rows in word_rows.items() if len(rows) >= min_rows and len(rows) <= max_rows)

# join the remaining words into a single string for each row
df['transcript_qQ2'] = df['transcript_qQ2'].apply(lambda x: ' '.join(word for word in x if word in remaining_words))

# %%
df['transcript_qQ3'] = df['transcript_qQ3'].apply(lambda x: x.split())

# count the frequency of each word
word_freq = Counter(word for words in df['transcript_qQ3'] for word in words)

# filter out words that appear only once
word_freq = {word: freq for word, freq in word_freq.items() if freq > 1}

# get the count of rows that each word appears in
word_rows = {}
for i, words in df['transcript_qQ3'].iteritems():
    for word in set(words):
        if word in word_freq and not word.isdigit():
            word_rows[word] = word_rows.get(word, set())
            word_rows[word].add(i)

# filter out words that appear in less than 50 rows or in more than 50% of the rows
min_rows = 50
max_rows = len(df) / 2
remaining_words = set(word for word, rows in word_rows.items() if len(rows) >= min_rows and len(rows) <= max_rows)

# join the remaining words into a single string for each row
df['transcript_qQ3'] = df['transcript_qQ3'].apply(lambda x: ' '.join(word for word in x if word in remaining_words))

# %%
df['transcript_qQ4'] = df['transcript_qQ4'].apply(lambda x: x.split())

# count the frequency of each word
word_freq = Counter(word for words in df['transcript_qQ4'] for word in words)

# filter out words that appear only once
word_freq = {word: freq for word, freq in word_freq.items() if freq > 1}

# get the count of rows that each word appears in
word_rows = {}
for i, words in df['transcript_qQ4'].iteritems():
    for word in set(words):
        if word in word_freq and not word.isdigit():
            word_rows[word] = word_rows.get(word, set())
            word_rows[word].add(i)

# filter out words that appear in less than 50 rows or in more than 50% of the rows
min_rows = 50
max_rows = len(df) / 2
remaining_words = set(word for word, rows in word_rows.items() if len(rows) >= min_rows and len(rows) <= max_rows)

# join the remaining words into a single string for each row
df['transcript_qQ4'] = df['transcript_qQ4'].apply(lambda x: ' '.join(word for word in x if word in remaining_words))

# %%
df = df.reset_index(drop=True)
df
# Out:
#             cik  year                                     transcript_qQ1  \
# 0        1800.0  2008  priority received arrangement co develop abbot...
# 1        1800.0  2010  tom pharmaceutical medical global pharmaceutic...
# 2        1800.0  2011  shared r rick went phase space rapidly watch h...
# 3        1800.0  2012  closer john news delivering double digit ongoi...
# 4        1800.0  2013  rare circumstance glad rely realize sound rati...
# ...         ...   ...                                                ...
# 5783  1561627.0  2013  appreciate chairman ceo dave burn john reviewi...
# 5784  1564822.0  2013  proactive initiate conversation reactive wait ...
# 5785  1564902.0  2013  gene entertainment excited public completion i...
# 5786  1569134.0  2013  okay count told urge annualize proxy sound eve...
# 5787  1575571.0  2013  yeah picked auto pacing scott afternoon statio...
#
#                                          transcript_qQ2  \
# 0     john phil wholesaler buying affected noted str...
# 1     responding fda shortly meet fda okay europe pr...
# 2     fingertip smaller mention mike went generic de...
# 3     tom vice finance larry divisional vice relatio...
# 4     concludes replay central relation www afternoo...
# ...                                                 ...
# 5783  appreciate chairman david burn john reviewing ...
# 5784  remember piece specialty portfolio private lab...
# 5785  jim afternoon onetime initial public offering ...
# 5786  jennifer afternoon appreciate afternoon david ...
# 5787  yeah acquired tv station station station 2q ye...
#
#                                          transcript_qQ3  \
# 0     possible division profitability bp pleasantly ...
# 1     mike basically raise fx lift somewhat settled ...
# 2     international piece doubled size five double d...
# 3     mile operational unfavorable emerging remained...
# 4     okay brian enabled deliver double digit despit...
# ...                                                 ...
# 5783  focusing carbon carbon play feature proving pr...
# 5784  absolute updating everything integration gone ...
# 5785  afternoon webcast live jim jim released closed...
# 5786  afternoon david ebitda dcf compare distributio...
# 5787  achievement scott vice television station rich...
#
#                                          transcript_qQ4  \
# 0     went fairly rigorous self evaluation outside t...
# 1     okay india healthy fit western tom track forec...
# 2     mile delivering double digit eps original eps ...
# 3     mile explain handle transition pre separation ...
# 4     okay brian achieved representing double digit ...
# ...                                                 ...
# 5783  david happy slide absorption recurring stop re...
# 5784  category accelerated translated absolute chang...
# 5785  ask jim attendance reference jamie afternoon r...
# 5786  extend west afternoon everybody jump public ty...
# 5787  overview achievement richard proud accomplishm...
#
#                                                     mda
# 0     broad health care patent protection license te...
# 1     broad health care patent protection license te...
# 2     broad health care patent protection license te...
# 3     broad health care patent protection license te...
# 4     broad health care patent protection license te...
# ...                                                 ...
# 5783  thereto constitute meaning 27a 21e cautionary ...
# 5784  week week week week week basic declared shareh...
# 5785  thereto supplementary numerous carefully speci...
# 5786  midstream detail strategically hydrocarbon bas...
# 5787  television station seven digital channel netwo...
#
# [5788 rows x 7 columns]

# %% [markdown]
# I decide to set a maximum for the amount of topics at 40 based on Li's paper. However, if the algorithm can not find 40 suitable topics it will keep less.

# %% [markdown]
# ## Topics Q1

# %%
# Applying BERTopic with its default values (transcripts Q1)
start = time.time()
topic_model1 = BERTopic(nr_topics=40,verbose=True, calculate_probabilities=False)
topics1 = topic_model1.fit_transform(df['transcript_qQ1'])
end = time.time()
print(end-start)
# Out:
# Batches:   0%|          | 0/181 [00:00<?, ?it/s]
# 2023-03-28 06:28:23,833 - BERTopic - Transformed documents to Embeddings
# 2023-03-28 06:29:19,246 - BERTopic - Reduced dimensionality
# 2023-03-28 06:29:19,914 - BERTopic - Clustered reduced embeddings
# 2023-03-28 06:31:06,785 - BERTopic - Reduced number of topics from 61 to 40
# 31786.523812770844

# %%
topic_model1.get_topic_info()
# Out:
#     Topic  Count                                      Name
# 0      -1   2082        -1_production_america_north_client
# 1       0   1000            0_patient_study_clinical_trial
# 2       1    389          1_network_wireless_design_mobile
# 3       2    243        2_client_solution_cloud_enterprise
# 4       3    203             3_store_brand_retail_consumer
# 5       4    192           4_europe_america_north_currency
# 6       5    186                5_energy_utility_power_gas
# 7       6    186          6_oil_drilling_barrel_production
# 8       7    112        7_advertising_digital_station_game
# 9       8     88              8_fuel_truck_intermodal_coal
# 10      9     77          9_aircraft_airline_airplane_fuel
# 11     10     75     10_backlog_award_construction_billion
# 12     11     72           11_brand_food_category_beverage
# 13     12     68            12_restaurant_guest_menu_store
# 14     13     66                   13_pulp_paper_mill_wood
# 15     14     64               14_rig_drilling_gulf_mexico
# 16     15     61        15_transaction_client_payment_bank
# 17     16     59             16_corn_fertilizer_crop_plant
# 18     17     56            17_ngl_gas_pipeline_processing
# 19     18     54                      18_coal_ton_mine_met
# 20     19     51              19_vehicle_car_battery_store
# 21     20     43         20_chemical_raw_specialty_organic
# 22     21     39    21_student_school_enrollment_education
# 23     22     38                   22_steel_scrap_ton_mill
# 24     23     36               23_hotel_room_brand_booking
# 25     24     25     24_shipment_trailer_sequentially_ship
# 26     25     24                 25_mine_gold_copper_ounce
# 27     26     21        26_dave_store_automotive_furniture
# 28     27     20              27_vessel_charter_ship_fleet
# 29     28     19                 28_screen_theater_3d_film
# 30     29     17          29_casino_property_gaming_ebitda
# 31     30     16        30_waste_recycling_collection_fuel
# 32     31     15               31_advance_loan_jones_paper
# 33     32     15              32_insurance_car_wash_andrew
# 34     33     15                    33_churn_pc_spend_arpu
# 35     34     14          34_machine_adjusted_client_spine
# 36     35     13   35_subscriber_content_radio_programming
# 37     36     13              36_lp_waste_ph_restructuring
# 38     37     11  37_patent_licensing_litigation_portfolio
# 39     38     10     38_solution_cyber_government_critical

# %%
df_q1 = pd.DataFrame({"Document": df['transcript_qQ1'], "Topic_Q1": topics1[0]})

# %%
df_q1
# Out:
#                                                Document  Topic_Q1
# 0     priority received arrangement co develop abbot...         0
# 1     tom pharmaceutical medical global pharmaceutic...         0
# 2     shared r rick went phase space rapidly watch h...         0
# 3     closer john news delivering double digit ongoi...         0
# 4     rare circumstance glad rely realize sound rati...         0
# ...                                                 ...       ...
# 5783  appreciate chairman ceo dave burn john reviewi...        10
# 5784  proactive initiate conversation reactive wait ...         3
# 5785  gene entertainment excited public completion i...        -1
# 5786  okay count told urge annualize proxy sound eve...        17
# 5787  yeah picked auto pacing scott afternoon statio...        -1
#
# [5788 rows x 2 columns]

# %%
df_q1.to_csv('topics_q1.csv', index=False)

# %% [markdown]
# ## Topics Q2

# %%
# Applying BERTopic with its default values (transcripts Q2)
start = time.time()
topic_model2 = BERTopic(nr_topics=40,verbose=True, calculate_probabilities=False)
topics2 = topic_model2.fit_transform(df['transcript_qQ2'])
end = time.time()
print(end-start)
# Out:
# Batches:   0%|          | 0/181 [00:00<?, ?it/s]
# 2023-03-28 15:19:34,614 - BERTopic - Transformed documents to Embeddings
# 2023-03-28 15:20:02,001 - BERTopic - Reduced dimensionality
# 2023-03-28 15:20:02,588 - BERTopic - Clustered reduced embeddings
# 2023-03-28 15:21:52,692 - BERTopic - Reduced number of topics from 70 to 40
# 31843.76603770256

# %%
topic_model2.get_topic_info()
# Out:
#     Topic  Count                                              Name
# 0      -1   2048                   -1_brand_consumer_europe_client
# 1       0    959                    0_patient_study_clinical_trial
# 2       1    496                     1_rig_drilling_oil_production
# 3       2    257                   2_network_cloud_solution_mobile
# 4       3    183                    3_europe_america_currency_asia
# 5       4    179               4_energy_utility_power_transmission
# 6       5    152                   5_design_semiconductor_wafer_q3
# 7       6    117                     6_store_brand_consumer_retail
# 8       7    108                         7_vehicle_car_store_truck
# 9       8    100                            8_steel_mill_ton_paper
# 10      9     91                  9_aircraft_airline_fuel_airplane
# 11     10     84                 10_bid_award_construction_backlog
# 12     11     82                       11_coal_ton_mine_production
# 13     12     80                12_bank_transaction_payment_client
# 14     13     78  13_europe_manufacturing_restructuring_industrial
# 15     14     70                14_client_license_booking_solution
# 16     15     66       15_advertising_station_advertiser_political
# 17     16     60                    16_restaurant_guest_menu_store
# 18     17     56                         17_corn_crop_food_ethanol
# 19     18     56                     18_freight_truck_fuel_vehicle
# 20     19     44                       19_brand_category_milk_beer
# 21     20     44                    20_hotel_room_booking_property
# 22     21     40                  21_property_casino_gaming_ebitda
# 23     22     33            22_student_enrollment_education_school
# 24     23     32              23_subscription_energy_student_waste
# 25     24     31          24_client_consultant_employee_consulting
# 26     25     30                       25_lumber_wood_acre_harvest
# 27     26     27                         26_ounce_gold_mine_silver
# 28     27     23                 27_vessel_fleet_charter_container
# 29     28     22                     28_consumer_energy_golf_slide
# 30     29     20                   29_royalty_patent_lte_licensing
# 31     30     17     30_exposure_occupancy_compensation_california
# 32     31     15                         31_jones_battery_soda_six
# 33     32     14                         32_screen_3d_theater_film
# 34     33     14            33_community_occupancy_living_property
# 35     34     13            34_crane_rental_equipment_construction
# 36     35     13                         35_crew_fiscal_canada_bid
# 37     36     12                          36_fund_client_fee_index
# 38     37     11              37_waste_recycling_landfill_republic
# 39     38     11                  38_club_membership_member_center

# %%
df_q2 = pd.DataFrame({"Document": df['transcript_qQ2'], "Topic_Q2": topics2[0]})

# %%
df_q2
# Out:
#                                                Document  Topic_Q2
# 0     john phil wholesaler buying affected noted str...         0
# 1     responding fda shortly meet fda okay europe pr...         0
# 2     fingertip smaller mention mike went generic de...         0
# 3     tom vice finance larry divisional vice relatio...         0
# 4     concludes replay central relation www afternoo...         0
# ...                                                 ...       ...
# 5783  appreciate chairman david burn john reviewing ...        13
# 5784  remember piece specialty portfolio private lab...        17
# 5785  jim afternoon onetime initial public offering ...        14
# 5786  jennifer afternoon appreciate afternoon david ...        -1
# 5787  yeah acquired tv station station station 2q ye...        15
#
# [5788 rows x 2 columns]

# %%
df_q2.to_csv('topics_q2.csv', index=False)

# %% [markdown]
# ## Topics Q3

# %%
# Applying BERTopic with its default values (transcripts Q3)
start = time.time()
topic_model3 = BERTopic(nr_topics=40,verbose=True, calculate_probabilities=False)
topics3 = topic_model3.fit_transform(df['transcript_qQ3'])
end = time.time()
print(end-start)
# Out:
# Batches:   0%|          | 0/181 [00:00<?, ?it/s]
# 2023-03-29 00:28:51,420 - BERTopic - Transformed documents to Embeddings
# 2023-03-29 00:29:08,189 - BERTopic - Reduced dimensionality
# 2023-03-29 00:29:08,895 - BERTopic - Clustered reduced embeddings
# 2023-03-29 00:31:09,666 - BERTopic - Reduced number of topics from 66 to 40
# 32954.18380069733

# %%
topic_model3.get_topic_info()
# Out:
#     Topic  Count                                    Name
# 0      -1   2193       -1_production_ebitda_north_europe
# 1       0    959          0_patient_study_clinical_trial
# 2       1    443            1_network_mobile_q4_solution
# 3       2    385           2_store_brand_consumer_retail
# 4       3    209             3_barrel_oil_gas_production
# 5       4    145         4_utility_energy_power_electric
# 6       5    139               5_vehicle_truck_car_fleet
# 7       6    122            6_slide_billion_backlog_john
# 8       7     95        7_aircraft_airline_fuel_airplane
# 9       8     92          8_rig_drilling_equipment_fleet
# 10      9     85   9_client_employee_consulting_solution
# 11     10     84          10_restaurant_menu_guest_store
# 12     11     79             11_coal_ton_mine_production
# 13     12     73       12_currency_america_europe_region
# 14     13     72              13_client_fund_firm_estate
# 15     14     58              14_corn_crop_ethanol_plant
# 16     15     53  15_waste_recycling_landfill_industrial
# 17     16     53     16_license_solution_software_client
# 18     17     46         17_banking_nine_bank_enterprise
# 19     18     38          18_hotel_room_booking_property
# 20     19     38                  19_paper_pulp_mill_eur
# 21     20     37     20_student_enrollment_campus_school
# 22     21     30             21_lumber_acre_harvest_land
# 23     22     26           22_coal_intermodal_train_rail
# 24     23     22       23_vessel_fleet_container_charter
# 25     24     21        24_currency_client_constant_knee
# 26     25     19               25_race_racing_gaming_cup
# 27     26     17  26_community_occupancy_living_resident
# 28     27     16          27_q4_benchmark_sector_booking
# 29     28     15        28_wheel_tire_slide_construction
# 30     29     15           29_casino_gaming_slot_printer
# 31     30     14    30_patent_licensing_royalty_licensee
# 32     31     13             31_coating_resin_north_auto
# 33     32     13        32_gas_ethylene_ethane_feedstock
# 34     33     12           33_boeing_alloy_shipment_mill
# 35     34     12               34_screen_3d_theater_film
# 36     35     12         35_check_web_institution_direct
# 37     36     11         36_subscriber_churn_center_arpu
# 38     37     11     37_club_membership_member_attrition
# 39     38     11       38_water_california_utility_usage

# %%
df_q3 = pd.DataFrame({"Document": df['transcript_qQ3'], "Topic_Q3": topics3[0]})

# %%
df_q3
# Out:
#                                                Document  Topic_Q3
# 0     possible division profitability bp pleasantly ...         0
# 1     mike basically raise fx lift somewhat settled ...         0
# 2     international piece doubled size five double d...         0
# 3     mile operational unfavorable emerging remained...        -1
# 4     okay brian enabled deliver double digit despit...         0
# ...                                                 ...       ...
# 5783  focusing carbon carbon play feature proving pr...        -1
# 5784  absolute updating everything integration gone ...        -1
# 5785  afternoon webcast live jim jim released closed...        10
# 5786  afternoon david ebitda dcf compare distributio...        -1
# 5787  achievement scott vice television station rich...         1
#
# [5788 rows x 2 columns]

# %%
df_q3.to_csv('topics_q3.csv', index=False)

# %% [markdown]
# ## Topics Q4

# %%
# Applying BERTopic with its default values (transcripts Q4)
start = time.time()
topic_model4 = BERTopic(nr_topics=40,verbose=True, calculate_probabilities=False)
topics4 = topic_model4.fit_transform(df['transcript_qQ4'])
end = time.time()
print(end-start)
# Out:
# Batches:   0%|          | 0/181 [00:00<?, ?it/s]
# 2023-03-29 10:21:01,110 - BERTopic - Transformed documents to Embeddings
# 2023-03-29 10:21:14,626 - BERTopic - Reduced dimensionality
# 2023-03-29 10:21:15,191 - BERTopic - Clustered reduced embeddings
# 2023-03-29 10:22:57,934 - BERTopic - Reduced number of topics from 63 to 40
# 35505.43538880348

# %%
topic_model4.get_topic_info()
# Out:
#     Topic  Count                                          Name
# 0      -1   1990                -1_america_europe_ebitda_slide
# 1       0   1005                0_patient_study_clinical_trial
# 2       1    544                        1_oil_rig_drilling_gas
# 3       2    331               2_network_cloud_mobile_solution
# 4       3    286                 3_brand_store_consumer_retail
# 5       4    166                    4_utility_energy_power_gas
# 6       5    143              5_america_currency_europe_brazil
# 7       6    110                   6_client_fund_solution_firm
# 8       7     97                    7_coal_ton_mine_production
# 9       8     95              8_aircraft_airplane_airline_fuel
# 10      9     92                9_backlog_construction_bid_job
# 11     10     70                 10_restaurant_menu_guest_food
# 12     11     69             11_consumer_payment_solution_loan
# 13     12     68              12_vehicle_car_europe_automotive
# 14     13     57         13_station_radio_political_subscriber
# 15     14     51  14_aftermarket_currency_solution_realignment
# 16     15     46                   15_hotel_room_brand_booking
# 17     16     42           16_student_enrollment_school_campus
# 18     17     41         17_freight_truckload_truck_intermodal
# 19     18     40                  18_vessel_charter_fleet_boat
# 20     19     40                  19_wafer_inch_foundry_memory
# 21     20     39                20_casino_gaming_property_vega
# 22     21     37                    21_corn_crop_ethanol_plant
# 23     22     31        22_license_renewal_subscription_client
# 24     23     30                    23_pulp_paper_mill_machine
# 25     24     29          24_advertising_digital_advertiser_ad
# 26     25     29                      25_ups_scott_air_package
# 27     26     25    26_organic_industrial_aerospace_automotive
# 28     27     22             27_chemical_ethylene_plant_ethane
# 29     28     20               28_solar_semiconductor_semi_led
# 30     29     18                29_coal_car_intermodal_railcar
# 31     30     17                   30_acre_harvest_lumber_land
# 32     31     17          31_patent_licensing_royalty_licensee
# 33     32     15              32_cabinet_remodel_paint_channel
# 34     33     14            33_employee_talent_staffing_client
# 35     34     13             34_water_golden_utility_regulated
# 36     35     13            35_laser_application_welding_power
# 37     36     12                     36_theater_screen_film_3d
# 38     37     12                37_rental_fleet_leasing_ebitda
# 39     38     12                38_battery_vehicle_grid_energy

# %%
df_q4 = pd.DataFrame({"Document": df['transcript_qQ4'], "Topic_Q4": topics4[0]})

# %%
df_q4
# Out:
#                                                Document  Topic_Q4
# 0     went fairly rigorous self evaluation outside t...         0
# 1     okay india healthy fit western tom track forec...         0
# 2     mile delivering double digit eps original eps ...         0
# 3     mile explain handle transition pre separation ...         0
# 4     okay brian achieved representing double digit ...         0
# ...                                                 ...       ...
# 5783  david happy slide absorption recurring stop re...        -1
# 5784  category accelerated translated absolute chang...        -1
# 5785  ask jim attendance reference jamie afternoon r...        20
# 5786  extend west afternoon everybody jump public ty...         1
# 5787  overview achievement richard proud accomplishm...        13
#
# [5788 rows x 2 columns]

# %%
df_q4.to_csv('topics_q4.csv', index=False)

# %% [markdown]
# ## Topics MDA

# %%
# Applying BERTopic with its default values (mda)
start = time.time()
topic_model5 = BERTopic(nr_topics=40,verbose=True, calculate_probabilities=False)
topics5 = topic_model5.fit_transform(df['mda'])
end = time.time()
print(end-start)
# Out:
# Batches:   0%|          | 0/181 [00:00<?, ?it/s]
# 2023-03-29 19:19:57,131 - BERTopic - Transformed documents to Embeddings
# 2023-03-29 19:20:12,132 - BERTopic - Reduced dimensionality
# 2023-03-29 19:20:12,824 - BERTopic - Clustered reduced embeddings
# 2023-03-29 19:23:12,195 - BERTopic - Reduced number of topics from 143 to 40
# 32416.916571378708

# %%
topic_model5.get_topic_info()
# Out:
#     Topic  Count                                          Name
# 0      -1   1404      -1_software_client_restructuring_network
# 1       0    525                    0_oil_gas_natural_drilling
# 2       1    440               1_clinical_trial_drug_milestone
# 3       2    434          2_client_software_license_consulting
# 4       3    283    3_semiconductor_wafer_design_restructuring
# 5       4    268         4_subscriber_network_wireless_station
# 6       5    235                        5_coal_mine_ton_mining
# 7       6    215                        6_food_paper_mill_pulp
# 8       7    205                7_store_retail_brand_wholesale
# 9       8    201               8_power_energy_electric_utility
# 10      9    146              9_software_solution_asia_channel
# 11     10    141              10_chemical_asbestos_pension_raw
# 12     11    138               11_health_care_medicare_medical
# 13     12    136        12_vehicle_dealership_automotive_store
# 14     13     88                  13_gaming_casino_resort_vega
# 15     14     77  14_restaurant_franchise_franchisees_operated
# 16     15     76           15_water_beverage_brand_concentrate
# 17     16     69                 16_freight_railroad_fuel_rail
# 18     17     68                17_vessel_charter_marine_fleet
# 19     18     65            18_aircraft_fuel_passenger_airline
# 20     19     62       19_construction_backlog_granite_ceiling
# 21     20     61      20_blood_laboratory_clinical_diagnostics
# 22     21     59            21_hotel_vacation_room_reservation
# 23     22     53    22_printer_advertising_digital_circulation
# 24     23     42              23_staffing_nurse_payroll_allied
# 25     24     40           24_reg_care_aesthetic_restructuring
# 26     25     39        25_student_education_institution_title
# 27     26     26                 26_estate_real_ebitda_leasing
# 28     27     24                      27_ca_defense_fa_pension
# 29     28     19             28_timberland_timber_harvest_acre
# 30     29     19                   29_welding_tie_steel_europe
# 31     30     17                  30_pool_cooling_heating_snow
# 32     31     17      31_tire_american_pension_rationalization
# 33     32     17             32_crane_foodservice_rental_coast
# 34     33     15             33_landfill_waste_closure_capping
# 35     34     14       34_pharmacy_prescription_drug_dispensed
# 36     35     13                   35_tobacco_brand_fda_excise
# 37     36     13             36_execute_trust_thereto_engaging
# 38     37     12             37_nasdaq_clearing_listing_nordic
# 39     38     12        38_community_living_resident_residence

# %%
df_mda = pd.DataFrame({"Document": df['mda'], "Topic_MDA": topics5[0]})

# %%
df_mda
# Out:
#                                                Document  Topic_MDA
# 0     broad health care patent protection license te...         -1
# 1     broad health care patent protection license te...         -1
# 2     broad health care patent protection license te...         -1
# 3     broad health care patent protection license te...         -1
# 4     broad health care patent protection license te...         -1
# ...                                                 ...        ...
# 5783  thereto constitute meaning 27a 21e cautionary ...         22
# 5784  week week week week week basic declared shareh...          6
# 5785  thereto supplementary numerous carefully speci...         13
# 5786  midstream detail strategically hydrocarbon bas...          0
# 5787  television station seven digital channel netwo...          4
#
# [5788 rows x 2 columns]

# %%
df_mda.to_csv('topics_mda.csv', index=False)

# %% [markdown]
# ## Merging all and extracting

# %%
df_all = pd.DataFrame({"cik": df['cik'], "year": df['year'], 'Topic_Q1': topics1[0],'Topic_Q2': topics2[0],
                       'Topic_Q3': topics3[0],'Topic_Q4': topics4[0],'Topic_MDA': topics5[0]})

# %%
df_all.to_csv('topic_features.csv')

# %%
df_all
# Out:
#             cik  year  Topic_Q1  Topic_Q2  Topic_Q3  Topic_Q4  Topic_MDA
# 0        1800.0  2008         0         0         0         0         -1
# 1        1800.0  2010         0         0         0         0         -1
# 2        1800.0  2011         0         0         0         0         -1
# 3        1800.0  2012         0         0        -1         0         -1
# 4        1800.0  2013         0         0         0         0         -1
# ...         ...   ...       ...       ...       ...       ...        ...
# 5783  1561627.0  2013        10        13        -1        -1         22
# 5784  1564822.0  2013         3        17        -1        -1          6
# 5785  1564902.0  2013        -1        14        10        20         13
# 5786  1569134.0  2013        17        -1        -1         1          0
# 5787  1575571.0  2013        -1        15         1        13          4
#
# [5788 rows x 7 columns]
